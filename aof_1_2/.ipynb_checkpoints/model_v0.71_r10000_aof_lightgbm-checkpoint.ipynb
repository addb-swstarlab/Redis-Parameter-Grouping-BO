# %% [markdown]
# # model
#
# * 이상치 제거 버전
# * 이상치 제거하지 않은 버전

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
from lightgbm import LGBMRegressor, plot_importance
from sklearn.metrics import roc_auc_score

# %%
# knob 종류 및 바운드
# aof

knobs_aof = {
    
    "hash-max-ziplist-entries":     (256, 751), 
    "hash-max-ziplist-value": (16, 257),
    "activerehashing": ('yes', 'no'),  ##yes
    "hz": (1, 41),
    "dynamic-hz": ('yes', 'no'),
    
    # appendonly 제외
    'appendfsync' :('always', 'everysec', 'no'),
    'auto-aof-rewrite-percentage': (50, 200),
    'auto-aof-rewrite-min-size': (16, 256),
    'no-appendfsync-on-rewrite': ('yes', 'no'),
    'aof-rewrite-incremental-fsync': ('yes', 'no'),
    'aof-use-rdb-preamble': ('yes', 'no'),


    "activedefrag": ('yes','no'),  
    "active-defrag-threshold-lower": (1, 31),
    "active-defrag-threshold-upper": (70, 101),
    "active-defrag-cycle-min": (1, 31),
    "active-defrag-cycle-max": (70, 91),
    
    "maxmemory": (1000, 2900),   ##"volatile-lru"
    "maxmemory-policy":     ("volatile-lru", "allkeys-lru", "volatile-lfu", "allkeys-lfu", 
                             "volatile-random","allkeys-random", "volatile-ttl", "noeviction"),
    "maxmemory-samples": (3, 7),
    
    "lazyfree-lazy-eviction": ('yes', 'no'),
    "lazyfree-lazy-expire": ('yes', 'no'),
    "lazyfree-lazy-server-del": ('yes', 'no')
}

knobs_list = list(knobs_aof.keys())
knobs_bound = list(knobs_aof.values())

# %% [markdown]
# ## 데이터 전처리
# * 이상치 파악
# * test, train 데이터 잘 나뉘어졌는지 확인

# %%
# internal role == master 인 부분 인덱스 계산
file_dir = '../data/'
file_name = 'internal_metrics_r10000_aof2.csv'

internal_csv = pd.read_csv(file_dir+file_name)
idx_role_null = internal_csv['role'] == 'master'

# %%
# config(knob) data
config_df = pd.read_csv("../data/result_config_r10000_aof.csv", sep=',')

# 1250 개 추출
config_df = config_df.iloc[0:1000,:]
config_df.shape

# external(throughput) data
# external_df = pd.read_csv("./data/external_metrics0.csv", sep=',')
external_df = pd.read_csv("../data/external_metrics_r10000_aof2.csv", sep=',')
# 1250 개 추출
external_df = external_df.iloc[0:1000,:]
external_df.shape
# Out:
# (1000, 39)

# %%
config_df.head(3)
# Out:
#   appendonly appendfsync  auto-aof-rewrite-percentage  \
# 0        yes    everysec                          155
# 1        yes          no                           93
# 2        yes      always                          175
#
#   auto-aof-rewrite-min-size no-appendfsync-on-rewrite  \
# 0                     118mb                        no
# 1                     244mb                        no
# 2                     134mb                        no
#
#   aof-rewrite-incremental-fsync aof-use-rdb-preamble  save0_0  save0_1  \
# 0                           yes                  yes      NaN      NaN
# 1                           yes                  yes      NaN      NaN
# 2                            no                  yes      NaN      NaN
#
#    save1_0  ...  maxmemory-policy  maxmemory-samples  lazyfree-lazy-eviction  \
# 0      NaN  ...      volatile-lru                  7                     yes
# 1      NaN  ...        noeviction                  6                      no
# 2      NaN  ...      volatile-lfu                  5                     yes
#
#    lazyfree-lazy-expire  lazyfree-lazy-server-del  hash-max-ziplist-entries  \
# 0                   yes                        no                       730
# 1                   yes                       yes                       439
# 2                   yes                       yes                       387
#
#   hash-max-ziplist-value  activerehashing  hz  dynamic-hz
# 0                    184               no   6          no
# 1                    216              yes  18         yes
# 2                    241              yes  16         yes
#
# [3 rows x 32 columns]

# %%
# config(knog), external(throughput) 데이터 하나의 프레임으로 결합
dataset = config_df
dataset['throughput'] = external_df['Gets_KB/sec']

# %%
# 결측치 처리 
dataset_nan = dataset.copy()
dataset['activedefrag'].fillna(value='no', inplace=True)  # activedefrag no 채우기
dataset = dataset.fillna(value = 0)  # 전부 0으로 채움

# %%
# role == master 제외
dataset = dataset[idx_role_null]

# %%
dataset
# Out:
#     appendonly appendfsync  auto-aof-rewrite-percentage  \
# 0          yes    everysec                          155
# 1          yes          no                           93
# 2          yes      always                          175
# 3          yes          no                          174
# 4          yes      always                          145
# ..         ...         ...                          ...
# 995        yes          no                          161
# 996        yes          no                          192
# 997        yes    everysec                           55
# 998        yes      always                          192
# 999        yes    everysec                          131
#
#     auto-aof-rewrite-min-size no-appendfsync-on-rewrite  \
# 0                       118mb                        no
# 1                       244mb                        no
# 2                       134mb                        no
# 3                        56mb                        no
# 4                       178mb                        no
# ..                        ...                       ...
# 995                     201mb                       yes
# 996                      69mb                        no
# 997                     113mb                        no
# 998                     150mb                        no
# 999                      69mb                       yes
#
#     aof-rewrite-incremental-fsync aof-use-rdb-preamble  save0_0  save0_1  \
# 0                             yes                  yes      0.0      0.0
# 1                             yes                  yes      0.0      0.0
# 2                              no                  yes      0.0      0.0
# 3                             yes                   no      0.0      0.0
# 4                              no                  yes      0.0      0.0
# ..                            ...                  ...      ...      ...
# 995                           yes                  yes      0.0      0.0
# 996                            no                  yes      0.0      0.0
# 997                           yes                   no      0.0      0.0
# 998                            no                  yes      0.0      0.0
# 999                           yes                  yes      0.0      0.0
#
#      save1_0  ...  maxmemory-samples  lazyfree-lazy-eviction  \
# 0        0.0  ...                  7                     yes
# 1        0.0  ...                  6                      no
# 2        0.0  ...                  5                     yes
# 3        0.0  ...                  3                     yes
# 4        0.0  ...                  3                     yes
# ..       ...  ...                ...                     ...
# 995      0.0  ...                  3                      no
# 996      0.0  ...                  5                      no
# 997      0.0  ...                  5                      no
# 998      0.0  ...                  6                      no
# 999      0.0  ...                  3                     yes
#
#      lazyfree-lazy-expire  lazyfree-lazy-server-del  hash-max-ziplist-entries  \
# 0                     yes                        no                       730
# 1                     yes                       yes                       439
# 2                     yes                       yes                       387
# 3                     yes                       yes                       475
# 4                      no                        no                       623
# ..                    ...                       ...                       ...
# 995                   yes                        no                       429
# 996                   yes                        no                       698
# 997                   yes                        no                       402
# 998                    no                       yes                       577
# 999                   yes                        no                       738
#
#      hash-max-ziplist-value activerehashing  hz  dynamic-hz  throughput
# 0                       184              no   6          no    51111.81
# 1                       216             yes  18         yes    45144.89
# 2                       241             yes  16         yes       17.56
# 3                       187              no   2          no    41590.07
# 4                        33              no   7          no       18.59
# ..                      ...             ...  ..         ...         ...
# 995                      49             yes   5          no    35386.89
# 996                      67             yes  27          no    44235.75
# 997                      51              no  24          no    44972.83
# 998                     189             yes  37          no       18.48
# 999                      93             yes  27         yes    48768.59
#
# [1000 rows x 33 columns]

# %%
# maxmemory knob 단위(mb) 처리
dataset['maxmemory']  = dataset['maxmemory'].str.strip('mb')
dataset['maxmemory'] = pd.to_numeric(dataset['maxmemory'])

# auto-aof-rewrite-min-size knob 단위(mb) 처리
dataset['auto-aof-rewrite-min-size']  = dataset['auto-aof-rewrite-min-size'].str.strip('mb')
dataset['auto-aof-rewrite-min-size'] = pd.to_numeric(dataset['auto-aof-rewrite-min-size'])

# %%
# Object 변수 categorical 로 변경 (LightGBM에 바로 넣기 위해)
category_knob = []

for knob in dataset:
    if dataset[knob].dtype == 'O':  # Object인 경우 category 형으로 변경
        dataset[knob] = dataset[knob].astype('category')
        if knob in knobs_list:
            category_knob.append(knob)

# %%
# 설정한 knob들만 추출
extract_knobs_list = knobs_list.copy()
extract_knobs_list.append('throughput')  # target 값 추가

dataset = dataset[extract_knobs_list]

# %%
# numeric_knob
numeric_knob = []

for knob in dataset:
    if dataset[knob].dtype == 'category':  # Object인 경우 category 형으로 변경
        continue
    numeric_knob.append(knob)

numeric_knob.remove('throughput')

# %%
dataset.head(3)
# Out:
#    hash-max-ziplist-entries  hash-max-ziplist-value activerehashing  hz  \
# 0                       730                     184              no   6
# 1                       439                     216             yes  18
# 2                       387                     241             yes  16
#
#   dynamic-hz appendfsync  auto-aof-rewrite-percentage  \
# 0         no    everysec                          155
# 1        yes          no                           93
# 2        yes      always                          175
#
#    auto-aof-rewrite-min-size no-appendfsync-on-rewrite  \
# 0                        118                        no
# 1                        244                        no
# 2                        134                        no
#
#   aof-rewrite-incremental-fsync  ... active-defrag-threshold-upper  \
# 0                           yes  ...                          74.0
# 1                           yes  ...                           0.0
# 2                            no  ...                           0.0
#
#   active-defrag-cycle-min  active-defrag-cycle-max  maxmemory  \
# 0                    22.0                     85.0       1000
# 1                     0.0                      0.0       1800
# 2                     0.0                      0.0       2500
#
#    maxmemory-policy  maxmemory-samples  lazyfree-lazy-eviction  \
# 0      volatile-lru                  7                     yes
# 1        noeviction                  6                      no
# 2      volatile-lfu                  5                     yes
#
#   lazyfree-lazy-expire  lazyfree-lazy-server-del throughput
# 0                  yes                        no   51111.81
# 1                  yes                       yes   45144.89
# 2                  yes                       yes      17.56
#
# [3 rows x 23 columns]

# %%
# 결측치 처리전 확인
print(dataset_nan.info())

# 결측치 처리후 확인
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   appendonly                     1000 non-null   object
#  1   appendfsync                    1000 non-null   object
#  2   auto-aof-rewrite-percentage    1000 non-null   int64
#  3   auto-aof-rewrite-min-size      1000 non-null   object
#  4   no-appendfsync-on-rewrite      1000 non-null   object
#  5   aof-rewrite-incremental-fsync  1000 non-null   object
#  6   aof-use-rdb-preamble           1000 non-null   object
#  7   save0_0                        0 non-null      float64
#  8   save0_1                        0 non-null      float64
#  9   save1_0                        0 non-null      float64
#  10  save1_1                        0 non-null      float64
#  11  save2_0                        0 non-null      float64
#  12  save2_1                        0 non-null      float64
#  13  rdbcompression                 0 non-null      float64
#  14  rdbchecksum                    0 non-null      float64
#  15  rdb-save-incremental-fsync     0 non-null      float64
#  16  activedefrag                   482 non-null    object
#  17  active-defrag-threshold-lower  482 non-null    float64
#  18  active-defrag-threshold-upper  482 non-null    float64
#  19  active-defrag-cycle-min        482 non-null    float64
#  20  active-defrag-cycle-max        482 non-null    float64
#  21  maxmemory                      1000 non-null   object
#  22  maxmemory-policy               1000 non-null   object
#  23  maxmemory-samples              1000 non-null   int64
#  24  lazyfree-lazy-eviction         1000 non-null   object
#  25  lazyfree-lazy-expire           1000 non-null   object
#  26  lazyfree-lazy-server-del       1000 non-null   object
#  27  hash-max-ziplist-entries       1000 non-null   int64
#  28  hash-max-ziplist-value         1000 non-null   int64
#  29  activerehashing                1000 non-null   object
#  30  hz                             1000 non-null   int64
#  31  dynamic-hz                     1000 non-null   object
#  32  throughput                     1000 non-null   float64
# dtypes: float64(14), int64(5), object(14)
# memory usage: 257.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   hash-max-ziplist-entries       1000 non-null   int64
#  1   hash-max-ziplist-value         1000 non-null   int64
#  2   activerehashing                1000 non-null   category
#  3   hz                             1000 non-null   int64
#  4   dynamic-hz                     1000 non-null   category
#  5   appendfsync                    1000 non-null   category
#  6   auto-aof-rewrite-percentage    1000 non-null   int64
#  7   auto-aof-rewrite-min-size      1000 non-null   int64
#  8   no-appendfsync-on-rewrite      1000 non-null   category
#  9   aof-rewrite-incremental-fsync  1000 non-null   category
#  10  aof-use-rdb-preamble           1000 non-null   category
#  11  activedefrag                   1000 non-null   category
#  12  active-defrag-threshold-lower  1000 non-null   float64
#  13  active-defrag-threshold-upper  1000 non-null   float64
#  14  active-defrag-cycle-min        1000 non-null   float64
#  15  active-defrag-cycle-max        1000 non-null   float64
#  16  maxmemory                      1000 non-null   int64
#  17  maxmemory-policy               1000 non-null   category
#  18  maxmemory-samples              1000 non-null   int64
#  19  lazyfree-lazy-eviction         1000 non-null   category
#  20  lazyfree-lazy-expire           1000 non-null   category
#  21  lazyfree-lazy-server-del       1000 non-null   category
#  22  throughput                     1000 non-null   float64
# dtypes: category(11), float64(5), int64(7)
# memory usage: 113.9 KB
# None

# %% [markdown]
# ### 이상치 처리

# %%
# # 이상치 인덱스 반환 함수
# def get_outlier(df=None, column=None, weight=1.5):
    
#     # target 값과 상관관계가 높은 열을 우선적으로 진행
#     quantile_25 = np.percentile(df[column].values, 25)
#     quantile_75 = np.percentile(df[column].values, 75)

#     IQR = quantile_75 - quantile_25
#     IQR_weight = IQR*weight

#     lowest = quantile_25 - IQR_weight
#     highest = quantile_75 + IQR_weight

#     outlier_idx = df[column][ (df[column] < lowest) | (df[column] > highest) ].index
#     return outlier_idx

# %%
# import seaborn as sns
# sns.boxplot(dataset['throughput'])

# %%
# outlier_index = get_outlier(dataset, 'throughput')

# # 이상치 제거
# dataset.drop(outlier_index, axis=0, inplace = True)
# sns.boxplot(dataset['throughput'])

# %%
# 타입 확인 (카테고리)
dataset.dtypes
# Out:
# hash-max-ziplist-entries            int64
# hash-max-ziplist-value              int64
# activerehashing                  category
# hz                                  int64
# dynamic-hz                       category
# appendfsync                      category
# auto-aof-rewrite-percentage         int64
# auto-aof-rewrite-min-size           int64
# no-appendfsync-on-rewrite        category
# aof-rewrite-incremental-fsync    category
# aof-use-rdb-preamble             category
# activedefrag                     category
# active-defrag-threshold-lower     float64
# active-defrag-threshold-upper     float64
# active-defrag-cycle-min           float64
# active-defrag-cycle-max           float64
# maxmemory                           int64
# maxmemory-policy                 category
# maxmemory-samples                   int64
# lazyfree-lazy-eviction           category
# lazyfree-lazy-expire             category
# lazyfree-lazy-server-del         category
# throughput                        float64
# dtype: object

# %% [markdown]
# ### test, train 데이터 분리

# %%
#  정확도 확인용 train 8, test 2
X_train_val, X_test, y_train_val, y_test = train_test_split(dataset.iloc[:,:-1]
                                                    , dataset['throughput'] 
                                                    ,test_size=0.2
                                                   , random_state = 156)

# train 8 val 2
X_train, X_val, y_train, y_val = train_test_split(X_train_val
                                                    , y_train_val 
                                                    ,test_size=0.2
                                                   , random_state = 156)


# # 전체 데이터 train 8, val 2
# X_train, X_val, y_train, y_val = train_test_split(dataset.iloc[:,:-1]
#                                                     , dataset['throughput'] 
#                                                     ,test_size=0.2
#                                                    , random_state = 156)

# %%
# # scaling
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(X_train[numeric_knob])  # x_train 스케일 기준 정보 적용

# X_train_index = list(X_train.index)  # X_train 인덱스
# X_train_scaled_numeric = scaler.transform(X_train[numeric_knob])  # transformation
# X_train_scaled_numeric_df = pd.DataFrame(X_train_scaled_numeric, columns = numeric_knob, index = X_train_index)  
# X_train_scaled_df = pd.concat([X_train_scaled_numeric_df, X_train[category_knob]], axis=1)  # 카테고리와 합치기

# X_val_index = list(X_val.index)  # X_val 인덱스
# X_val_scaled_numeric = scaler.transform(X_val[numeric_knob])  # transformation
# X_val_scaled_numeric_df = pd.DataFrame(X_val_scaled_numeric, columns = numeric_knob, index = X_val_index)  
# X_val_scaled_df = pd.concat([X_val_scaled_numeric_df, X_val[category_knob]], axis=1)  # 카테고리와 합치기


# # X_test_index = list(X_test.index)  # X_train 인덱스
# # X_test_scaled_numeric = scaler.transform(X_test[numeric_knob])  # transformation
# # X_test_scaled_numeric_df = pd.DataFrame(X_test_scaled_numeric, columns = numeric_knob, index = X_test_index)  
# # X_test_scaled_df = pd.concat([X_test_scaled_numeric_df, X_test[category_knob]], axis=1)  # 카테고리와 합치기

# %%
# # test, train 에 비슷하게 분류됬는지 확인
# y_train.hist()
# plt.title('train data')
# plt.show()

# y_test.hist()
# plt.title('test data')
# plt.show()

# %% [markdown]
# ## LightGBM 모델 생성

# %%
# 모델 객체 생성, n_estimators = 400으로 설정
lgbm_wrapper = LGBMRegressor(n_estimators=1000, learning_rate=0.1)

# 검증 데이터(validation data)
evals = [(X_val, y_val)]

lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='auc',
                eval_set = evals, verbose = True, categorical_feature=category_knob)
# Out:
# [1]	valid_0's auc: 1	valid_0's l2: 3.74804e+08
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's auc: 1	valid_0's l2: 3.22484e+08
# [3]	valid_0's auc: 1	valid_0's l2: 2.78839e+08
# [4]	valid_0's auc: 1	valid_0's l2: 2.43629e+08
# [5]	valid_0's auc: 1	valid_0's l2: 2.15531e+08
# [6]	valid_0's auc: 1	valid_0's l2: 1.92094e+08
# [7]	valid_0's auc: 1	valid_0's l2: 1.74184e+08
# [8]	valid_0's auc: 1	valid_0's l2: 1.59022e+08
# [9]	valid_0's auc: 1	valid_0's l2: 1.46758e+08
# [10]	valid_0's auc: 1	valid_0's l2: 1.36106e+08
# [11]	valid_0's auc: 1	valid_0's l2: 1.27979e+08
# [12]	valid_0's auc: 1	valid_0's l2: 1.20854e+08
# [13]	valid_0's auc: 1	valid_0's l2: 1.16281e+08
# [14]	valid_0's auc: 1	valid_0's l2: 1.13003e+08
# [15]	valid_0's auc: 1	valid_0's l2: 1.09101e+08
# [16]	valid_0's auc: 1	valid_0's l2: 1.06836e+08
# [17]	valid_0's auc: 1	valid_0's l2: 1.04038e+08
# [18]	valid_0's auc: 1	valid_0's l2: 1.02192e+08
# [19]	valid_0's auc: 1	valid_0's l2: 1.00404e+08
# [20]	valid_0's auc: 1	valid_0's l2: 9.98991e+07
# [21]	valid_0's auc: 1	valid_0's l2: 9.92031e+07
# [22]	valid_0's auc: 1	valid_0's l2: 9.88199e+07
# [23]	valid_0's auc: 1	valid_0's l2: 9.82414e+07
# [24]	valid_0's auc: 1	valid_0's l2: 9.80029e+07
# [25]	valid_0's auc: 1	valid_0's l2: 9.80457e+07
# [26]	valid_0's auc: 1	valid_0's l2: 9.82848e+07
# [27]	valid_0's auc: 1	valid_0's l2: 9.76963e+07
# [28]	valid_0's auc: 1	valid_0's l2: 9.8493e+07
# [29]	valid_0's auc: 1	valid_0's l2: 9.85158e+07
# [30]	valid_0's auc: 1	valid_0's l2: 9.84987e+07
# [31]	valid_0's auc: 1	valid_0's l2: 9.88151e+07
# [32]	valid_0's auc: 1	valid_0's l2: 9.98679e+07
# [33]	valid_0's auc: 1	valid_0's l2: 1.00022e+08
# [34]	valid_0's auc: 1	valid_0's l2: 9.96695e+07
# [35]	valid_0's auc: 1	valid_0's l2: 9.9756e+07
# [36]	valid_0's auc: 1	valid_0's l2: 9.93173e+07
# [37]	valid_0's auc: 1	valid_0's l2: 9.93453e+07
# [38]	valid_0's auc: 1	valid_0's l2: 9.98162e+07
# [39]	valid_0's auc: 1	valid_0's l2: 9.9678e+07
# [40]	valid_0's auc: 1	valid_0's l2: 9.99115e+07
# [41]	valid_0's auc: 1	valid_0's l2: 1.00211e+08
# [42]	valid_0's auc: 1	valid_0's l2: 1.00454e+08
# [43]	valid_0's auc: 1	valid_0's l2: 1.00462e+08
# [44]	valid_0's auc: 1	valid_0's l2: 1.00112e+08
# [45]	valid_0's auc: 1	valid_0's l2: 1.01003e+08
# [46]	valid_0's auc: 1	valid_0's l2: 1.00841e+08
# [47]	valid_0's auc: 1	valid_0's l2: 1.01135e+08
# [48]	valid_0's auc: 1	valid_0's l2: 1.01541e+08
# [49]	valid_0's auc: 1	valid_0's l2: 1.01898e+08
# [50]	valid_0's auc: 1	valid_0's l2: 1.02751e+08
# [51]	valid_0's auc: 1	valid_0's l2: 1.03015e+08
# [52]	valid_0's auc: 1	valid_0's l2: 1.03267e+08
# [53]	valid_0's auc: 1	valid_0's l2: 1.04024e+08
# [54]	valid_0's auc: 1	valid_0's l2: 1.03977e+08
# [55]	valid_0's auc: 1	valid_0's l2: 1.04222e+08
# [56]	valid_0's auc: 1	valid_0's l2: 1.04284e+08
# [57]	valid_0's auc: 1	valid_0's l2: 1.05173e+08
# [58]	valid_0's auc: 1	valid_0's l2: 1.04935e+08
# [59]	valid_0's auc: 1	valid_0's l2: 1.05657e+08
# [60]	valid_0's auc: 1	valid_0's l2: 1.06145e+08
# [61]	valid_0's auc: 1	valid_0's l2: 1.06365e+08
# [62]	valid_0's auc: 1	valid_0's l2: 1.0619e+08
# [63]	valid_0's auc: 1	valid_0's l2: 1.06077e+08
# [64]	valid_0's auc: 1	valid_0's l2: 1.06141e+08
# [65]	valid_0's auc: 1	valid_0's l2: 1.06555e+08
# [66]	valid_0's auc: 1	valid_0's l2: 1.06567e+08
# [67]	valid_0's auc: 1	valid_0's l2: 1.07206e+08
# [68]	valid_0's auc: 1	valid_0's l2: 1.0731e+08
# [69]	valid_0's auc: 1	valid_0's l2: 1.07592e+08
# [70]	valid_0's auc: 1	valid_0's l2: 1.07859e+08
# [71]	valid_0's auc: 1	valid_0's l2: 1.08261e+08
# [72]	valid_0's auc: 1	valid_0's l2: 1.08499e+08
# [73]	valid_0's auc: 1	valid_0's l2: 1.08667e+08
# [74]	valid_0's auc: 1	valid_0's l2: 1.0859e+08
# [75]	valid_0's auc: 1	valid_0's l2: 1.0896e+08
# [76]	valid_0's auc: 1	valid_0's l2: 1.09075e+08
# [77]	valid_0's auc: 1	valid_0's l2: 1.08958e+08
# [78]	valid_0's auc: 1	valid_0's l2: 1.09321e+08
# [79]	valid_0's auc: 1	valid_0's l2: 1.09497e+08
# [80]	valid_0's auc: 1	valid_0's l2: 1.09835e+08
# [81]	valid_0's auc: 1	valid_0's l2: 1.10076e+08
# [82]	valid_0's auc: 1	valid_0's l2: 1.10232e+08
# [83]	valid_0's auc: 1	valid_0's l2: 1.10273e+08
# [84]	valid_0's auc: 1	valid_0's l2: 1.10269e+08
# [85]	valid_0's auc: 1	valid_0's l2: 1.10452e+08
# [86]	valid_0's auc: 1	valid_0's l2: 1.104e+08
# [87]	valid_0's auc: 1	valid_0's l2: 1.10531e+08
# [88]	valid_0's auc: 1	valid_0's l2: 1.10816e+08
# [89]	valid_0's auc: 1	valid_0's l2: 1.10977e+08
# [90]	valid_0's auc: 1	valid_0's l2: 1.11245e+08
# [91]	valid_0's auc: 1	valid_0's l2: 1.11328e+08
# [92]	valid_0's auc: 1	valid_0's l2: 1.11177e+08
# [93]	valid_0's auc: 1	valid_0's l2: 1.11192e+08
# [94]	valid_0's auc: 1	valid_0's l2: 1.11577e+08
# [95]	valid_0's auc: 1	valid_0's l2: 1.11903e+08
# [96]	valid_0's auc: 1	valid_0's l2: 1.12346e+08
# [97]	valid_0's auc: 1	valid_0's l2: 1.12663e+08
# [98]	valid_0's auc: 1	valid_0's l2: 1.13063e+08
# [99]	valid_0's auc: 1	valid_0's l2: 1.13261e+08
# [100]	valid_0's auc: 1	valid_0's l2: 1.13521e+08
# [101]	valid_0's auc: 1	valid_0's l2: 1.13577e+08
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1	valid_0's l2: 3.74804e+08
# LGBMRegressor(n_estimators=1000)

# %% [markdown]
# ## 성능 평가

# %%
# 성능 측정 함수 RMSLE(캐글에서 요구한 성능 평가 방법), MSE, RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
# log 값 변환 시 NaN 등의 이슈로 log()가 아닌 log1p()를 이용해 RMSLE 계산 
def rmsle(y, pred):
    # log1p 변환
    log_y = np.log1p(y)
    log_pred = np.log1p(pred)
    
    # squred 계산
    squared_error = (log_y-log_pred)**2
    
    # RMSE 계산
    rmsle = np.sqrt(np.mean(squared_error))
    
    return rmsle

# 사이킷런의 mean_square_error()를 이용해 RMSE 계산
def rmse(y, pred):
    return np.sqrt(mean_squared_error(y, pred))

# MSE, RMSE, RMSLE를 모두 계산
def evaluate_regr(y, pred):
    rmsle_val = rmsle(y, pred)
    rmse_val = rmse(y, pred)
    
    # MAE는 사이킷런의 mean_absolute_error()로 계산
    mae_val = mean_absolute_error(y, pred)
    
    print('RMSLE: {0:.3f}, RMSE: {1:.3F}, MAE: {2:.3F}'.format(rmsle_val, rmse_val, mae_val))

# %%
# preds = lgbm_wrapper.predict(X_test_scaled_df)  # 예측 결과
# evaluate_regr(y_test, preds)

# %%
# lgbm_wrapper.predict(X_test.iloc[3:4,:])

# %%
# plot_importance()를 이영해 피처 중요도 시각화
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgbm_wrapper, ax= ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
# # 디폴트 값 넣어보기
# default_val = {

#     'hash-max-ziplist-entries': [512],
#     'hash-max-ziplist-value': [64],
#     'activerehashing': ['yes'],
#     'hz': [10],
#     'dynamic-hz': ['yes'],
#     'save0_0': [900],
#     'save0_1':[1],
#     'save1_0': [300],
#     'save1_1':[10],
#     'save2_0': [60],
#     'save2_1':[10000],
#     'rdbcompression': ['yes'],
#     'rdbchecksum': ['yes'],
#     'rdb-save-incremental-fsync': ['yes'],
#     'activedefrag': ['yes'],
#     'active-defrag-threshold-lower': [10],
#     'active-defrag-threshold-upper': [100],
#     'active-defrag-cycle-min': [5],
#     'active-defrag-cycle-max': [75],
#     'maxmemory': [0],
#     'maxmemory-policy':['noeviction'],
#     'maxmemory-samples': [5],
#     'lazyfree-lazy-eviction': ['no'],
#     'lazyfree-lazy-expire': ['no'],
#     'lazyfree-lazy-server-del': ['no']

# }

# default_df = pd.DataFrame(default_val)
        

# for knob in default_df:
#     if default_df[knob].dtype == 'O':  # Object인 경우 category 형으로 변경
#         default_df[knob] = default_df[knob].astype('category')

# %%
# lgbm_wrapper.predict(default_df)

# %% [markdown]
# ---

# %% [markdown]
# ### 하이퍼파라미터 튜닝

# %%
# from sklearn.model_selection import GridSearchCV

# # 하이퍼파라미터 튜닝시 수행 속도를 향상시키기 위해 n_estimators를 200으로 감소
# lgbm_wrapper = LGBMRegressor(n_estimators = 200)

# params = {
#     'num_leaves':[32, 64],
#     'max_depth':[128, 160],
#     'min_child_samples':[60, 100],
#     'subsample':[0.8, 1]
# }

# # cv는 3으로 가정 (교차 검증을 자동으로 해주는건가?)
# gridcv = GridSearchCV(lgbm_wrapper, param_grid = params, cv=3)
# gridcv.fit(X_train, y_train, early_stopping_rounds = 30, eval_metric='auc', 
#           eval_set = [(X_train, y_train), (X_test, y_test)])

# print('GridSeaerchCV 최적 파라미터:', gridcv.best_params_)

# %%
# # 하이퍼 파라미터 적용 후 다시 생성
# lgbm_wrapper = LGBMRegressor(n_estimators = 1000,
#                             num_leaves = 32,
#                             subsample=0.8,
#                             min_child_samples=60,
#                             max_depth=128)

# evals = [(X_test, y_test)]

# lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=100,
#                 eval_metric='auc',
#                 eval_set=evals,
#                 verbose=True)

# %% [markdown]
# ---

# %% [markdown]
# # BO

# %%
def knob_to_dict(knob_dict):
    for key, val in knob_dict.items():
                
        if 'yes' in key:
            if val == 0:
                continue
            elif val == 1:
                print(key[:-4], end=' ')
                print('yes')
                continue
        elif 'no' in key:
            if val == 0:
                continue
            elif val == 1:
                print(key[:-3], end=' ')
                print('no')
                continue        

        if 'auto-aof-rewrite-min-size' in key:
            print(key, end=' ')
            print(val, end = '')
            print('mb')
            continue
        
        if 'appendfsync' in key:
            print(key, end=' ')
            print(val, )
            continue
                
        if 'maxmemory' in key:
            if 'policy' in key:
                if val == 1:
                    print('maxmemory-policy', end=' ')
                    print(key[17:])
                    continue
                
                elif val == 0:
                    continue
            elif len(key) == 9:
                print(key, end=' ')
                print(val, end='')
                print('mb')
                continue                        

                
        print(key, end=' ')
        print(val)

def knob_to_dict2(knob_dict):
    for key, val in knob_dict.items():
                        
        if 'save' in key:
            if key == 'rdb-save-incremental-fsync':
                print(key, end=' ')
                print(val)
                continue
            
            if key[6] == '0':
                print('save', end=' ')
                print(val, end=' ')
            elif key[6] == '1':
                print(val)
            continue
        
        if key == 'maxmemory':
            print(key, end=' ')
            print(val,end='')
            print('mb')
            continue
                        
        print(key, end=' ')
        print(val)

# %% [markdown]
# ## 목적함수

# %%
noise_level = 0.1

def objective_func(knob_value, noise_level=noise_level):

    knob_dict = {}
    for knob in knobs_list: # 순서에 맞게 선언
        knob_dict[knob] = 'x'
    
#     print('###x 삽입###')
#     print(knob_dict)
    
    # knob_value 값 먼저 할당
    for idx,knob in enumerate(knobs):
        knob_dict[knob] = knob_value[idx]
    
#     print('##먼저할당##')
#     print(knob_dict)
    
    
    # 나머지 값 채우기 
    for knob ,knob_val in knob_dict.items():
        if knob_val == 'x':
            knob_dict[knob] = knobs_update[knob]
            
#     print('##나머지 update 반영 할당##')
#     print(knob_dict)
                    
    if 'activedefrag' in knob_dict:
        if knob_dict['activedefrag'] == 'no':  # activedefrag no인 경우 나머지 관련 knob들에 0할당!
            activ_var = ['active-defrag-threshold-lower', 'active-defrag-threshold-upper', 'active-defrag-cycle-min', 'active-defrag-cycle-max']
            for activ_knob in activ_var:
                knob_dict[activ_knob] = 0     
    
    knob_df = pd.DataFrame(knob_dict, index=[0])  # 데이터 프레임으로 변환
#     print(knob_df)
    
    # 카테고리 변수 변경
    for knob in category_knob:
        knob_df[knob] = knob_df[knob].astype('category') 
    
    
    return -lgbm_wrapper.predict(knob_df)[0]

# %% [markdown]
# ## gp_minimize

# %%
# %matplotlib inline
print(__doc__)

import numpy as np
np.random.seed(237)
import matplotlib.pyplot as plt
from skopt.plots import plot_gaussian_process
from skopt import gp_minimize
# Out:
# Automatically created module for IPython interactive environment

# %%
cluster_table = {
    
        'clsuter0':[        
        # cluster1
        'active-defrag-threshold-lower',
        'active-defrag-cycle-min' ,
        'hash-max-ziplist-entries', 
        'hash-max-ziplist-value' ,
        'hz' ,
        'auto-aof-rewrite-percentage' ,
        'maxmemory' ,
        'dynamic-hz' ,
        'aof-use-rdb-preamble' ,
        'lazyfree-lazy-eviction', 
    ],
    
    'cluster1':[
        # cluster0
        'active-defrag-threshold-upper', 
        'active-defrag-cycle-max' ,
        'auto-aof-rewrite-min-size', 
        'maxmemory-samples',     
        'activerehashing',
        'no-appendfsync-on-rewrite',
        'aof-rewrite-incremental-fsync',
        'lazyfree-lazy-expire' ,
        'lazyfree-lazy-server-del',
     ],
}
knobs_update = {
    
    'hash-max-ziplist-entries': 512,
    'hash-max-ziplist-value': 64,
    'activerehashing': 'yes',
    'hz': 10,
    'dynamic-hz': 'yes',

#     'appendonly': 'yes',
    'appendfsync': 'everysec',
    'auto-aof-rewrite-percentage': 100,
    'auto-aof-rewrite-min-size': 64,  # mb
    'no-appendfsync-on-rewrite': "no", 
    'aof-rewrite-incremental-fsync': 'yes', 
    'aof-use-rdb-preamble': 'yes',

    'activedefrag': 'yes',
    'active-defrag-threshold-lower': 10,
    'active-defrag-threshold-upper': 100,
    'active-defrag-cycle-min': 5,
    'active-defrag-cycle-max': 75,
    "maxmemory": 0,
    'maxmemory-policy': 'noeviction',
    'maxmemory-samples': 5,
    'lazyfree-lazy-eviction': 'no',
    'lazyfree-lazy-expire':'no',
    'lazyfree-lazy-server-del': 'no'

}

# %%
res_result = []
knob_update_list = []

for i in range(1):
    print('###########{}##########'.format(i))
    
    iter_per_res = 0
    
    for cluster, knobs in cluster_table.items():
        print('#####{}#####'.format(cluster))
        gp_knobs_bound = []

        # 1. 클러스터의 bound 생성
#         print('{} bound 생성'.format(cluster))
        for knob in knobs: 
            gp_knobs_bound.append(knobs_aof[knob])

#         print('{} gp 진행'.format(cluster))
        # 2. gp_minimize 진행
        res = gp_minimize(

                    objective_func,                  # 목적함수
                    gp_knobs_bound,      # bound
                    random_state=np.random.randint(1,1234),
            
                    acq_func="EI",      
                    n_calls=30,      # 총 반복 횟수
                    n_random_starts=5,    # 초기 랜덤 값
                    noise=0.1**2,       
        )   

        # 결과 knob 값들
#         print('{} gp 완료'.format(cluster))
        res_result.append(res)
        gp_result = res.x
        iter_per_res = res.fun
                
        for idx,knob in enumerate(knobs):
            knobs_update[knob] = gp_result[idx]
        
        knob_update_list.append(knobs_update.copy())
        
        print('{}-th'.format(i))
        print(res.func_vals)
        print(res.fun)
        
    print(iter_per_res)
    print()
# Out:
# ###########0##########
# #####clsuter0#####
# 0-th
# [-30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30621.44311575 -30845.87284433 -30621.44311575 -30845.87284433
#  -30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30845.87284433 -30845.87284433]
# -30845.872844334226
# #####cluster1#####
# 0-th
# [-30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30793.96186945 -30845.87284433 -30793.96186945 -30845.87284433
#  -30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30845.87284433 -30845.87284433 -30845.87284433 -30845.87284433
#  -30845.87284433 -30845.87284433]
# -30845.872844334226
# -30845.872844334226

# %% [markdown]
# * 예측값: 30845.872844334226
#
# * 예측조합
# hash-max-ziplist-entries 582
# hash-max-ziplist-value 84
# activerehashing yes
# hz 34
# dynamic-hz no
# appendfsync everysec
# auto-aof-rewrite-percentage 165
# auto-aof-rewrite-min-size 184mb
# no-appendfsync-on-rewrite yes
# aof-rewrite-incremental-fsync yes
# aof-use-rdb-preamble no
# activedefrag yes
# active-defrag-threshold-lower 28
# active-defrag-threshold-upper 93
# active-defrag-cycle-min 23
# active-defrag-cycle-max 82
# maxmemory 2604mb
# maxmemory-policy noeviction
# maxmemory-samples 7
# lazyfree-lazy-eviction yes
# lazyfree-lazy-expire no
# lazyfree-lazy-server-del yes

# %%
# update 조합 
knob_to_dict(knob_update_list[1])
# Out:
# hash-max-ziplist-entries 582
# hash-max-ziplist-value 84
# activerehashing yes
# hz 34
# dynamic-hz no
# appendfsync everysec
# auto-aof-rewrite-percentage 165
# auto-aof-rewrite-min-size 184mb
# no-appendfsync-on-rewrite yes
# aof-rewrite-incremental-fsync yes
# aof-use-rdb-preamble no
# activedefrag yes
# active-defrag-threshold-lower 28
# active-defrag-threshold-upper 93
# active-defrag-cycle-min 23
# active-defrag-cycle-max 82
# maxmemory 2604mb
# maxmemory-policy noeviction
# maxmemory-samples 7
# lazyfree-lazy-eviction yes
# lazyfree-lazy-expire no
# lazyfree-lazy-server-del yes

# %% [markdown]
# ### 전체 knob 대상( 60440.76670625305 )

# %%
# 전체 데이터 대상
res_result_T = []

cluster_table_T = {

    'clsuter1':
    [
        "hash-max-ziplist-entries",
        'hash-max-ziplist-value', 
        'activerehashing' ,
        'hz' ,
        'dynamic-hz' ,
#         'appendonly' ,
        'appendfsync' ,
        'auto-aof-rewrite-percentage', 
        "auto-aof-rewrite-min-size" ,
        'no-appendfsync-on-rewrite' ,
        'aof-rewrite-incremental-fsync', 
        'aof-use-rdb-preamble', 
        'activedefrag' ,
        'active-defrag-threshold-lower' ,
        'active-defrag-threshold-upper', 
        'active-defrag-cycle-min' ,
        'active-defrag-cycle-max' ,
        'maxmemory' ,
        "maxmemory-policy" ,
        'maxmemory-samples',
        'lazyfree-lazy-eviction', 
        'lazyfree-lazy-expire' ,
        'lazyfree-lazy-server-del',        
               ]
}

knobs_update = {
        "hash-max-ziplist-entries":'x',
        'hash-max-ziplist-value':'x', 
        'activerehashing' :'x',
        'hz' :'x',
        'dynamic-hz' :'x',
#         'appendonly' :'x',
        'appendfsync' :'x',
        'auto-aof-rewrite-percentage':'x', 
        "auto-aof-rewrite-min-size" :'x',
        'no-appendfsync-on-rewrite' :'x',
        'aof-rewrite-incremental-fsync':'x', 
        'aof-use-rdb-preamble':'x', 
        'activedefrag' :'x',
        'active-defrag-threshold-lower' :'x',
        'active-defrag-threshold-upper':'x', 
        'active-defrag-cycle-min' :'x',
        'active-defrag-cycle-max' :'x',
        'maxmemory' :'x',
        "maxmemory-policy" :'x',
        'maxmemory-samples':'x',
        'lazyfree-lazy-eviction':'x', 
        'lazyfree-lazy-expire' :'x',
        'lazyfree-lazy-server-del':'x',        
}


for i in range(1):
    print('###########{}##########'.format(i))
    
    iter_per_res = 0
    
    for cluster, knobs in cluster_table_T.items():
        print('#####{}#####'.format(cluster))
        gp_knobs_bound = []

        # 1. 클러스터의 bound 생성
#         print('{} bound 생성'.format(cluster))
        for knob in knobs: 
            gp_knobs_bound.append(knobs_aof[knob])

#         print('{} gp 진행'.format(cluster))
        # 2. gp_minimize 진행
        res = gp_minimize(

                    objective_func,                  # 목적함수
                    gp_knobs_bound,      # bound
                    random_state=np.random.randint(1,1234),
#                     x0 = x0_list,
#                     y0 = y0_val, 
            
                    acq_func="EI",      
                    n_calls=30,      # 총 반복 횟수
                    n_random_starts=5,    # 초기 랜덤 값
                    noise=0.1**2,       
        )   

        # 결과 knob 값들
#         print('{} gp 완료'.format(cluster))
        gp_result = res.x
        iter_per_res = res.fun
        res_result_T.append(res)
        
        for idx,knob in enumerate(knobs):
            knobs_update[knob] = gp_result[idx]
        
        print('{}-th'.format(i))
        print(res.func_vals)
        print(res.fun)
        
    print(iter_per_res)
    print()
# Out:
# ###########0##########
# #####clsuter1#####
# 0-th
# [-30468.61966095 -30793.96186945 -30229.12416175 -30074.81518001
#  -27179.25007389 -30220.25643718 -27106.31857278 -30489.76939127
#  -27106.31857278 -27106.31857278 -27106.31857278 -26235.9582844
#  -30378.4258386  -30540.17093606 -30793.96186945 -30844.13890651
#  -30844.13890651 -30074.81518001 -30540.17093606 -30793.96186945
#  -30489.76939127 -30621.44311575 -30844.13890651 -30540.17093606
#  -29735.91052475 -30845.87284433 -29546.49233929 -30220.25643718
#  -30844.13890651 -30793.96186945]
# -30845.872844334226
# -30845.872844334226

# %% [markdown]
# * 예측값 :30845.872844334226
#
# * 예측 조합
# hash-max-ziplist-entries 256
# hash-max-ziplist-value 16
# activerehashing yes
# hz 41
# dynamic-hz yes
# appendfsync everysec
# auto-aof-rewrite-percentage 200
# auto-aof-rewrite-min-size 256mb
# no-appendfsync-on-rewrite yes
# aof-rewrite-incremental-fsync no
# aof-use-rdb-preamble no
# activedefrag yes
# active-defrag-threshold-lower 31
# active-defrag-threshold-upper 101
# active-defrag-cycle-min 1
# active-defrag-cycle-max 70
# maxmemory 1000mb
# maxmemory-policy allkeys-lfu
# maxmemory-samples 7
# lazyfree-lazy-eviction no
# lazyfree-lazy-expire yes
# lazyfree-lazy-server-del no

# %%
knob_to_dict2(knobs_update)
# Out:
# hash-max-ziplist-entries 256
# hash-max-ziplist-value 16
# activerehashing yes
# hz 41
# dynamic-hz yes
# appendfsync everysec
# auto-aof-rewrite-percentage 200
# auto-aof-rewrite-min-size 256
# no-appendfsync-on-rewrite yes
# aof-rewrite-incremental-fsync no
# aof-use-rdb-preamble no
# activedefrag yes
# active-defrag-threshold-lower 31
# active-defrag-threshold-upper 101
# active-defrag-cycle-min 1
# active-defrag-cycle-max 70
# maxmemory 1000mb
# maxmemory-policy allkeys-lfu
# maxmemory-samples 7
# lazyfree-lazy-eviction no
# lazyfree-lazy-expire yes
# lazyfree-lazy-server-del no

# %%
knobs_update
# Out:
# {'hash-max-ziplist-entries': 423,
#  'hash-max-ziplist-value': 85,
#  'activerehashing': 'yes',
#  'hz': 34,
#  'dynamic-hz': 'no',
#  'appendfsync': 'everysec',
#  'auto-aof-rewrite-percentage': 197,
#  'auto-aof-rewrite-min-size': 217,
#  'no-appendfsync-on-rewrite': 'yes',
#  'aof-rewrite-incremental-fsync': 'no',
#  'aof-use-rdb-preamble': 'yes',
#  'activedefrag': 'yes',
#  'active-defrag-threshold-lower': 6,
#  'active-defrag-threshold-upper': 98,
#  'active-defrag-cycle-min': 11,
#  'active-defrag-cycle-max': 89,
#  'maxmemory': 1911,
#  'maxmemory-policy': 'allkeys-lfu',
#  'maxmemory-samples': 5,
#  'lazyfree-lazy-eviction': 'yes',
#  'lazyfree-lazy-expire': 'yes',
#  'lazyfree-lazy-server-del': 'no'}

# %% [markdown]
# ---
