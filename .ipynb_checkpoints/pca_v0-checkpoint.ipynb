# %% [markdown]
# # 상관분석
#
# * internal_metrics() 이상치를 한번 파악하려고 봤더니 상자그림이 이상하게 그려졌다. 25
# * knob 이상치 제거할 필요 없다. 랜덤생성했기 때문에 14 (+ 범주형은 10개)
#
# 1. 데이터 전처리
# 2. 상관분석 함수
# 3. activedefrag 있는 경우
# 4. 전체 knob
# 5. activedefrag 없는 경우
# 6. pointbeir~

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cluster0 =[ 
'used_memory_rss',
'used_memory_rss_human',
'rss_overhead_ratio',
'rss_overhead_bytes',
'mem_fragmentation_ratio',
'mem_fragmentation_bytes']

cluster1 = [
    'uptime_in_seconds',
    'hz',
    'lru_clock',
    'used_memory_peak',
    'maxmemory',
    'maxmemory_human',
    'rdb_last_save_time',
    'total_net_output_bytes',
    'used_cpu_sys',
    'used_cpu_user'
]

cluster2 = [
    'allocator_allocated',
    'allocator_active',
    'allocator_frag_bytes',
    'instantaneous_ops_per_sec',
    'instantaneous_input_kbps',
    'instantaneous_output_kbps'
]

cluster3 = [
    'allocator_resident',
    'allocator_rss_ratio',
    'allocator_rss_bytes'  
]

knob_list = [
    "save0_0",
    "save0_1",
    "save1_0",
    "save1_1",
    "save2_0",
    "save2_1",

    "rdbcompression",
    "rdbchecksum",
    "rdb-save-incremental-fsync",

    "activedefrag",
    "active-defrag-threshold-lower",
    "active-defrag-threshold-upper",
    "active-defrag-cycle-min",
    "active-defrag-cycle-max",
    
    "maxmemory",
    
    "maxmemory-policy",
    "maxmemory-samples",
    "lazyfree-lazy-eviction",
    "lazyfree-lazy-expire",
    "lazyfree-lazy-server-del",

    "hash-max-ziplist-entries", 
    "hash-max-ziplist-value",
    "activerehashing",
    "hz",
    "dynamic-hz"
]

activedefrag_knobs = [
    "activedefrag",
    "active-defrag-threshold-lower",
    "active-defrag-threshold-upper",
    "active-defrag-cycle-min",
    "active-defrag-cycle-max",
]

# %%
# 데이터 불러오기 internal metrics와 knob들의 상관관계분석
internal_csv = pd.read_csv('./data/internal_metrcis0.csv')

# %%
# 데이터 불러오기 knob_list
knobs = pd.read_csv('./data/result_config0.csv')

# %%
# 컬럼 추출 함수
def extract_data(cluster_list, df):
    extracted_df = pd.DataFrame()
    for elem in cluster_list:
        extracted_df[elem] = df[elem]

    return extracted_df

# %% [markdown]
# ## 데이터 전처리

# %%
# 클러스터 합치기
cluster = cluster0+cluster1+cluster2+cluster3

# %%
# 클러스터 요소에 해당되는 metrics 25개 추출
total_internal_df = extract_data(cluster, internal_csv)

# %%
# throughput 결측치 제거
total_internal_df.dropna()
# Out:
#       allocator_resident  allocator_rss_ratio  allocator_rss_bytes
# 0               42209280                 1.08              3276800
# 1               44310528                 1.14              5378048
# 2               42209280                 1.08              3276800
# 3               42209280                 1.08              3276800
# 4               42209280                 1.08              3276800
# ...                  ...                  ...                  ...
# 2495            42160128                 1.08              3186688
# 2496            44310528                 1.14              5378048
# 2497            42209280                 1.08              3276800
# 2498            44310528                 1.14              5378048
# 2499            42209280                 1.08              3276800
#
# [2500 rows x 3 columns]

# %%
# internal_csv 결측치 확인 -> 없음!
total_internal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   used_memory_rss            2500 non-null   int64
#  1   used_memory_rss_human      2500 non-null   float64
#  2   rss_overhead_ratio         2500 non-null   float64
#  3   rss_overhead_bytes         2500 non-null   int64
#  4   mem_fragmentation_ratio    2500 non-null   float64
#  5   mem_fragmentation_bytes    2500 non-null   int64
#  6   uptime_in_seconds          2500 non-null   int64
#  7   hz                         2500 non-null   int64
#  8   lru_clock                  2500 non-null   int64
#  9   used_memory_peak           2500 non-null   int64
#  10  maxmemory                  2500 non-null   int64
#  11  maxmemory_human            2500 non-null   float64
#  12  rdb_last_save_time         2500 non-null   int64
#  13  total_net_output_bytes     2500 non-null   int64
#  14  used_cpu_sys               2500 non-null   float64
#  15  used_cpu_user              2500 non-null   float64
#  16  allocator_allocated        2500 non-null   int64
#  17  allocator_active           2500 non-null   int64
#  18  allocator_frag_bytes       2500 non-null   int64
#  19  instantaneous_ops_per_sec  2500 non-null   int64
#  20  instantaneous_input_kbps   2500 non-null   float64
#  21  instantaneous_output_kbps  2500 non-null   float64
#  22  allocator_resident         2500 non-null   int64
#  23  allocator_rss_ratio        2500 non-null   float64
#  24  allocator_rss_bytes        2500 non-null   int64
# dtypes: float64(9), int64(16)
# memory usage: 488.4 KB

# %% [markdown]
# ---

# %% [markdown]
# ### internal metrics 이상치 살펴보기

# %%
total_internal_df.describe()
# Out:
#        used_memory_rss  used_memory_rss_human  rss_overhead_ratio  \
# count     2.500000e+03            2500.000000         2500.000000
# mean      4.207360e+07              40.124768            0.991436
# std       4.147295e+05               0.395534            0.021341
# min       4.098048e+07              39.080000            0.940000
# 25%       4.202496e+07              40.080000            1.000000
# 50%       4.203725e+07              40.090000            1.000000
# 75%       4.204544e+07              40.100000            1.000000
# max       4.804608e+07              45.820000            1.140000
#
#        rss_overhead_bytes  mem_fragmentation_ratio  mem_fragmentation_bytes  \
# count        2.500000e+03              2500.000000             2.500000e+03
# mean        -5.099684e+05                 1.090748             3.453319e+06
# std          9.027010e+05                 0.010715             4.165163e+05
# min         -2.519040e+06                 1.080000             3.094024e+06
# 25%         -2.017280e+05                 1.090000             3.398256e+06
# 50%         -1.761280e+05                 1.090000             3.414640e+06
# 75%         -1.638400e+05                 1.090000             3.435120e+06
# max          5.832704e+06                 1.250000             9.465400e+06
#
#        uptime_in_seconds          hz     lru_clock  used_memory_peak  ...  \
# count        2500.000000  2500.00000  2.500000e+03      2.500000e+03  ...
# mean           23.957600    20.28280  1.784688e+06      3.870462e+07  ...
# std            65.636013    11.68667  2.254466e+04      3.209071e+00  ...
# min            21.000000     1.00000  1.745211e+06      3.870461e+07  ...
# 25%            22.000000    10.00000  1.766024e+06      3.870462e+07  ...
# 50%            22.000000    20.00000  1.784190e+06      3.870462e+07  ...
# 75%            24.000000    31.00000  1.803112e+06      3.870462e+07  ...
# max          3304.000000    40.00000  1.823806e+06      3.870464e+07  ...
#
#        used_cpu_user  allocator_allocated  allocator_active  \
# count    2500.000000         2.500000e+03      2.500000e+03
# mean        4.163159         3.866506e+07      3.893605e+07
# std         0.241795         3.358719e+04      3.599793e+04
# min         3.659209         3.780169e+07      3.806413e+07
# 25%         3.982597         3.865640e+07      3.892019e+07
# 50%         4.135503         3.865818e+07      3.893248e+07
# 75%         4.348494         3.865838e+07      3.893248e+07
# max         8.621078         3.874042e+07      3.902259e+07
#
#        allocator_frag_bytes  instantaneous_ops_per_sec  \
# count           2500.000000                 2500.00000
# mean          270996.726400                40140.20800
# std             5679.228417                14887.43939
# min           258120.000000                    0.00000
# 25%           264096.000000                29570.50000
# 50%           274096.000000                42173.00000
# 75%           274296.000000                51794.50000
# max           283096.000000                68288.00000
#
#        instantaneous_input_kbps  instantaneous_output_kbps  \
# count               2500.000000                2500.000000
# mean                2802.785976                 199.200700
# std                 1039.513849                  73.693757
# min                    0.000000                   0.000000
# 25%                 2064.757500                 146.875000
# 50%                 2944.690000                 209.270000
# 75%                 3616.540000                 256.792500
# max                 4768.220000                 338.470000
#
#        allocator_resident  allocator_rss_ratio  allocator_rss_bytes
# count        2.500000e+03          2500.000000         2.500000e+03
# mean         4.258357e+07             1.090808         3.647517e+06
# std          8.081961e+05             0.023054         8.081445e+05
# min          4.124262e+07             1.080000         3.178496e+06
# 25%          4.220928e+07             1.080000         3.276800e+06
# 50%          4.220928e+07             1.080000         3.276800e+06
# 75%          4.220928e+07             1.080000         3.289088e+06
# max          4.431872e+07             1.140000         5.398528e+06
#
# [8 rows x 25 columns]

# %%
# 동일한 값이 여러개 나오는 듯 하다.  -> 보통 둘쓕 날쑥해야 되는거 아닌가? 정규분포 모양처럼...?

# 히스토그램 
import seaborn as sns
total_internal_df['used_memory_rss'].hist(bins=22)
plt.show()
# # 상자그림
# sns.boxplot(data = total_internal_df, x='used_memory_rss')

# %%
index1 = total_internal_df['used_memory_rss'] < 43000000
t1 = total_internal_df['used_memory_rss'][index1]
index2 = t1 >= 42000000
t2 = t1[index2]
# t3 = np.log(t2)
# sns.boxplot(data = t2)
internal0_index = t2.index

# %%
sns.histplot(total_internal_df['used_memory_rss'])
# Out:
# <AxesSubplot:xlabel='used_memory_rss', ylabel='Count'>

# %%
# knob 
t_knob = subTotal_knobs['save2_0'][internal0_index]

# %%
t_knob
# Out:
# 0       36
# 1       82
# 2       36
# 4       61
# 5       52
#         ..
# 2494    43
# 2496    50
# 2497    43
# 2498    67
# 2499    84
# Name: save2_0, Length: 2265, dtype: int64

# %%
spearmanr(t3, t_knob)
# Out:
# SpearmanrResult(correlation=0.01582122146006602, pvalue=0.45169315516918274)

# %%
for knob in subTotal_knobs:
    t_knob = subTotal_knobs[knob][internal0_index]
    print(kendalltau(t2, t_knob))
# Out:
# KendalltauResult(correlation=-0.002025408315838687, pvalue=0.8897750512195195)
# KendalltauResult(correlation=-0.021021122610322955, pvalue=0.17183876483333282)
# KendalltauResult(correlation=-0.0008074822061565247, pvalue=0.9559384183932368)
# KendalltauResult(correlation=-0.011807398797733059, pvalue=0.421089502932001)
# KendalltauResult(correlation=-0.01135250593188759, pvalue=0.4404574495963198)
# KendalltauResult(correlation=-0.026806222428444052, pvalue=0.06631743216682383)
# KendalltauResult(correlation=0.016338041884613852, pvalue=0.3606136097823738)
# KendalltauResult(correlation=-0.013760744219762725, pvalue=0.4413096313594925)
# KendalltauResult(correlation=0.024806634581364582, pvalue=0.16511959980108248)
# KendalltauResult(correlation=nan, pvalue=nan)
# KendalltauResult(correlation=nan, pvalue=nan)
# KendalltauResult(correlation=nan, pvalue=nan)
# KendalltauResult(correlation=nan, pvalue=nan)
# KendalltauResult(correlation=nan, pvalue=nan)
# KendalltauResult(correlation=0.003648124940499782, pvalue=0.8072874888278466)
# KendalltauResult(correlation=-0.008400155121665694, pvalue=0.5873872652569683)
# KendalltauResult(correlation=0.00023445627726227726, pvalue=0.9883000958847428)
# KendalltauResult(correlation=-0.005939565560011553, pvalue=0.7396258323422327)
# KendalltauResult(correlation=0.013661170277210276, pvalue=0.44462181085160724)
# KendalltauResult(correlation=0.014826779577721919, pvalue=0.4067459287747057)
# KendalltauResult(correlation=0.005965810698069128, pvalue=0.6830503818166013)
# KendalltauResult(correlation=-0.012604689636663844, pvalue=0.38882508560029505)
# KendalltauResult(correlation=-0.04788091157492035, pvalue=0.007380262597981409)
# KendalltauResult(correlation=-0.1111409498210024, pvalue=5.414988521411926e-14)
# KendalltauResult(correlation=0.01345360516728459, pvalue=0.451571554310766)

# %%
for knob in subTotal_knobs:
    print(kendalltau(total_internal_df.iloc[:,0], subTotal_knobs[knob]))
# Out:
# KendalltauResult(correlation=-0.011888992127931234, pvalue=0.3893526753066844)
# KendalltauResult(correlation=-0.022560210041926737, pvalue=0.12076877680111256)
# KendalltauResult(correlation=0.010168996799093787, pvalue=0.4615723023060204)
# KendalltauResult(correlation=0.005355266894528384, pvalue=0.699412602176356)
# KendalltauResult(correlation=-0.0037714170111861674, pvalue=0.7862542657277285)
# KendalltauResult(correlation=-0.027572314544906606, pvalue=0.045655759442744547)
# KendalltauResult(correlation=0.02328986561733993, pvalue=0.16791895570267268)
# KendalltauResult(correlation=-0.01679382465862508, pvalue=0.32007155586789526)
# KendalltauResult(correlation=0.024784052276349167, pvalue=0.14227061364936025)
# KendalltauResult(correlation=nan, pvalue=nan)
# KendalltauResult(correlation=nan, pvalue=nan)
# KendalltauResult(correlation=nan, pvalue=nan)
# KendalltauResult(correlation=nan, pvalue=nan)
# KendalltauResult(correlation=nan, pvalue=nan)
# KendalltauResult(correlation=0.008885921526910959, pvalue=0.529553760837326)
# KendalltauResult(correlation=-0.0009517670675416312, pvalue=0.9481288680358904)
# KendalltauResult(correlation=0.0008829221208520543, pvalue=0.9534013577950524)
# KendalltauResult(correlation=-0.007067437951538256, pvalue=0.6756244783557552)
# KendalltauResult(correlation=-0.0003667436560015657, pvalue=0.9826762818828713)
# KendalltauResult(correlation=0.018028403301939527, pvalue=0.2857883312147207)
# KendalltauResult(correlation=0.012418859843730952, pvalue=0.36845021777047227)
# KendalltauResult(correlation=-0.011290296125768666, pvalue=0.4140613784456618)
# KendalltauResult(correlation=-0.036870776009119616, pvalue=0.0290354007062814)
# KendalltauResult(correlation=-0.0944662931033865, pvalue=1.3376469271151397e-11)
# KendalltauResult(correlation=-0.0015161254738362284, pvalue=0.9284738513065681)

# %% [markdown]
# ---

# %%
# maxmemory 처리 throughtput은 처리할 필요없다.
total_internal_df['maxmemory']
# Out:
# 0       2831155200
# 1       2306867200
# 2       1782579200
# 3       1048576000
# 4       1992294400
#            ...
# 2495    2936012800
# 2496    1572864000
# 2497    3040870400
# 2498    2306867200
# 2499    1468006400
# Name: maxmemory, Length: 2500, dtype: int64

# %%
# maxmemory 처리 knob
knobs['maxmemory'] = knobs['maxmemory'].str.strip('mb')  # 단위 자르기
knobs['maxmemory'] = pd.to_numeric(knobs['maxmemory'])  # 숫자형으로 바꾸기

# %% [markdown]
# ### activedefrag 처리
# * subTotal_knobs_Active : 약 1300개 이며 activedefrag가 있는 경우
# * subTotal_knobs_NoActive: 약 1300개 이며 activedefrag가 nan값으로 제거한 경우
# * subTotal_knobs_T : 2500개 이며 activedefrag 상관없이 전체 데이터
#
#
# * total_internal_Active : 약 1300개 이며 activedefrag가 있는 경우
# * total_internal_NoActive: 약 1300개 이며 activedefrag가 nan값으로 제거한 경우
# * total_internal_T : 2500개 이며 activedefrag 상관없이 전체 데이터

# %%
# knob_list 만 추출, AOF 관련 제외
subTotal_knobs = extract_data(knob_list, knobs)

# %%
# activedefrag knobs 분리

# activedefrag O 존재
subTotal_knobs_Active = subTotal_knobs.dropna()
Active_index = list(subTotal_knobs_Active.index)  # 인덱스

# activedefrag X 존재하지 않는 나머지 반
subTotal_knobs_NoActive = subTotal_knobs.loc[subTotal_knobs['activedefrag'].isna()].dropna(axis=1)
NoActive_index = list(subTotal_knobs_NoActive.index)  # 인덱스

# activedefrag O and X 전체 
subTotal_knobs_T = subTotal_knobs.dropna(axis=1)
total_index = list(subTotal_knobs_T.index)   # 인덱스

# %%
# knobs에서 타입별로 분리 (수치, 불리언, 불리언아닌 문자)

def varType(subTotal_knobs):
    object_var = []
    numerical_var = []  # 문자, 숫자 타입
    
    for idx in subTotal_knobs.dtypes.index:
        if subTotal_knobs.dtypes[idx] == 'O':  # 문자일 경우
            object_var.append(idx)
        else: 
            numerical_var.append(idx)  # 숫자일 경우

    boolean_var = []
    booleanNo_var = []  # 2개, 2개이상

    for col in object_var:
        col_count = len(subTotal_knobs[col].unique())

        if col_count == 2:  # 2개일 경우
            boolean_var.append(col)
        elif col_count > 2:  # 2개 이상일 경우
            booleanNo_var.append(col)
    
    return numerical_var, boolean_var, booleanNo_var

# 수치, 불리언, 불리언아닌것 (전체)
numerical_var, boolean_var, NobooleanNo_var = varType(subTotal_knobs_T)

# 수치, 불리언, 불리언아닌것 (activedefrag)
numericalActive_var, booleanActive_var, NobooleanNoActive_var = varType(subTotal_knobs_Active)

# 수치, 불리언, 불리언아닌것 (activedefrag 없는것)
numericalNoActive_var, booleanNoActive_var, NobooleanNoActive_var = varType(subTotal_knobs_NoActive)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3102b00d35c1> in <module>
#      25
#      26 # 수치, 불리언, 불리언아닌것 (전체)
# ---> 27 numerical_var, boolean_var, NobooleanNo_var = varType(subTotal_knobs_T)
#      28
#      29 # 수치, 불리언, 불리언아닌것 (activedefrag)
#
# NameError: name 'subTotal_knobs_T' is not defined

# %%
# activedefrag O
total_internal_Active = total_internal_df.iloc[Active_index]

# activedefrag X
total_internal_NoActive = total_internal_df.iloc[NoActive_index]

# activedefrag O and X
total_internal_T = total_internal_df.iloc[total_index]

# %% [markdown]
# ---

# %% [markdown]
# ## 상관분석 함수

# %%
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau


# knob하나 internal 여러개 상관계수 구하기

# pearson
## 모수 검정
def cal_pearsonr(knobs, internal_df):
    df = pd.DataFrame(columns = ['corr', 'p-value'])
    for internal in internal_df:
        result = pearsonr(knobs, internal_df[internal])
        df.loc[internal] = [result[0], result[1]]
    return df

# kendall
## 변수값 대신 순위로 바꿔서 이용, 비모수 검정
## 샘플사이저 적거나, 데이터 동률이 많을 때 유용
def cal_kendalltau(knobs, internal_df):
    df = pd.DataFrame(columns = ['corr', 'p-value'])
    for internal in internal_df:
        result = kendalltau(knobs, internal_df[internal])
        df.loc[internal] = [result[0], result[1]]
    return df

# 스피어만
## 변수값 대신 순위로 바꿔서 이용, 비모수 검정
## 데이터 내 편차와 에러에 만감하며, 일반적으로 켄달보다 높은 값을 가진다.
def cal_spearmanr(knobs, internal_df):
    df = pd.DataFrame(columns = ['corr', 'p-value'])
    for internal in internal_df:
        result = spearmanr(knobs, internal_df[internal])
        df.loc[internal] = [result[0], result[1]]
    return df

# %%
# knob 하나별로 3가지 상관분석 수행
def extract_pvalue(knobs, internal_df):
    print('pearson')
    df = cal_pearsonr(knobs, internal_df)
    is_pvalue = df['p-value'] <= 0.05
    print(df[is_pvalue])
    print()
    
    print('kendalltau')
    df = cal_kendalltau(knobs, internal_df)
    is_pvalue = df['p-value'] <= 0.05
    print(df[is_pvalue])
    print()
    
    print('spearman')
    df = cal_spearmanr(knobs, internal_df)
    is_pvalue = df['p-value'] <= 0.05
    print(df[is_pvalue])
    print()

# knob 리스트 각각 별로 extract_pvalue 수행
def extract_pvalue_knob(knob_list, subTotal_knobs, total_internal):
    for knob in knob_list:
        print('###{}###'.format(knob))
        extract_pvalue(subTotal_knobs[knob], total_internal)

# %% [markdown]
# ---

# %% [markdown]
# ## activedefrag 상관계수
# * subTotal_knobs_Active
# * total_internal_Active
#
# ### numericalActive_var :
# * active-defrag-threshold-lower
# * active-defrag-threshold-upper
# * active-defrag-cycle-min
# * active-defrag-cycle-max

# %%
numericalActive_var
numericalActive_var_new = numericalActive_var[6:10]
numericalActive_var_new
# Out:
# ['active-defrag-threshold-lower',
#  'active-defrag-threshold-upper',
#  'active-defrag-cycle-min',
#  'active-defrag-cycle-max']

# %%
extract_pvalue_knob(numericalActive_var_new, subTotal_knobs_Active,total_internal_Active)
# Out:
# ###active-defrag-threshold-lower###
# pearson
#                          corr   p-value
# allocator_resident   0.055844  0.048207
# allocator_rss_ratio  0.057253  0.042821
# allocator_rss_bytes  0.056016  0.047520
#
# kendalltau
#                         corr  p-value
# rss_overhead_ratio -0.051988  0.02251
#
# spearman
#                         corr   p-value
# rss_overhead_ratio -0.064179  0.023149
#
# ###active-defrag-threshold-upper###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###active-defrag-cycle-min###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###active-defrag-cycle-max###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []

# %%
# cluster 별 knob들의 상관계수 합  
active_result = pd.DataFrame(index = numericalActive_var_new)

cluster_list = [cluster0, cluster1, cluster2, cluster3]

for idx, cluster in enumerate(cluster_list):
    cluster_val = []
    for knob in numericalActive_var_new:
        df = cal_pearsonr(subTotal_knobs_Active[knob], total_internal_Active.loc[:,cluster])
        cluster_val.append(df['corr'].abs().sum())

    active_result['cluster'+str(idx)] = cluster_val

# %%
active_result
# Out:
#                                cluster0  cluster1  cluster2  cluster3
# active-defrag-threshold-lower  0.107440  0.250392  0.081287  0.169114
# active-defrag-threshold-upper  0.210770  0.155932  0.233161  0.055846
# active-defrag-cycle-min        0.143515  0.214407  0.144289  0.089408
# active-defrag-cycle-max        0.062975  0.182104  0.079199  0.024199

# %% [markdown]
# ---

# %% [markdown]
# ## 전체 knob
# * subTotal_knobs_T
# * total_internal_T
#
# ### numerical_var

# %%
numerical_var
# Out:
# ['save0_0',
#  'save0_1',
#  'save1_0',
#  'save1_1',
#  'save2_0',
#  'save2_1',
#  'maxmemory',
#  'maxmemory-samples',
#  'hash-max-ziplist-entries',
#  'hash-max-ziplist-value',
#  'hz']

# %%
extract_pvalue_knob(numerical_var, subTotal_knobs_T,total_internal_T)
# Out:
# ###save0_0###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
#                             corr   p-value
# mem_fragmentation_ratio -0.03388  0.036831
#
# spearman
#                              corr   p-value
# mem_fragmentation_ratio -0.041749  0.036861
#
# ###save0_1###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###save1_0###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
#                              corr   p-value
# mem_fragmentation_ratio  0.032439  0.045625
# allocator_resident       0.037987  0.015417
#
# spearman
#                              corr   p-value
# mem_fragmentation_ratio  0.040057  0.045217
# allocator_resident       0.048404  0.015503
#
# ###save1_1###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###save2_0###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###save2_1###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
#                      corr   p-value
# used_memory_rss -0.027572  0.045656
# maxmemory_human  0.028675  0.035971
#
# spearman
#                      corr   p-value
# used_memory_rss -0.039668  0.047347
# maxmemory_human  0.042248  0.034664
#
# ###maxmemory###
# pearson
#                      corr       p-value
# maxmemory        1.000000  0.000000e+00
# maxmemory_human -0.384509  6.815876e-89
#
# kendalltau
#                      corr  p-value
# maxmemory        1.000000      0.0
# maxmemory_human  0.787847      0.0
#
# spearman
#                      corr  p-value
# maxmemory        1.000000      0.0
# maxmemory_human  0.697009      0.0
#
# ###maxmemory-samples###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
#                      corr   p-value
# maxmemory_human  0.033546  0.025072
#
# spearman
#                      corr   p-value
# maxmemory_human  0.044978  0.024519
#
# ###hash-max-ziplist-entries###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###hash-max-ziplist-value###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###hz###
# pearson
#                                corr       p-value
# hz                         1.000000  0.000000e+00
# lru_clock                  0.042221  3.477663e-02
# rdb_last_save_time         0.042162  3.503412e-02
# used_cpu_sys               0.046259  2.072200e-02
# allocator_allocated       -0.176843  5.194381e-19
# allocator_active          -0.180201  1.086181e-19
# allocator_frag_bytes      -0.096348  1.391404e-06
# instantaneous_ops_per_sec -0.228475  5.751916e-31
# instantaneous_input_kbps  -0.228475  5.752184e-31
# instantaneous_output_kbps -0.227200  1.243844e-30
#
# kendalltau
#                                corr       p-value
# used_memory_rss           -0.094466  1.337647e-11
# used_memory_rss_human     -0.095079  6.954584e-11
# rss_overhead_bytes        -0.073846  9.115009e-08
# mem_fragmentation_bytes    0.050671  2.241485e-04
# hz                         1.000000  0.000000e+00
# lru_clock                  0.028479  3.500098e-02
# rdb_last_save_time         0.028479  3.500098e-02
# used_cpu_sys               0.032549  1.596561e-02
# allocator_allocated       -0.112218  1.989831e-16
# allocator_active          -0.118883  4.006975e-14
# instantaneous_ops_per_sec -0.184048  2.850712e-42
# instantaneous_input_kbps  -0.184044  2.858230e-42
# instantaneous_output_kbps -0.183039  7.923407e-42
# allocator_rss_bytes        0.097110  1.534741e-10
#
# spearman
#                                corr       p-value
# used_memory_rss           -0.131143  4.632050e-11
# used_memory_rss_human     -0.126949  1.889287e-10
# rss_overhead_bytes        -0.104218  1.765197e-07
# mem_fragmentation_bytes    0.078167  9.139660e-05
# hz                         1.000000  0.000000e+00
# lru_clock                  0.041922  3.608518e-02
# rdb_last_save_time         0.041922  3.608518e-02
# used_cpu_sys               0.048284  1.576192e-02
# allocator_allocated       -0.163662  1.801906e-16
# allocator_active          -0.153087  1.404462e-14
# instantaneous_ops_per_sec -0.267578  2.991234e-42
# instantaneous_input_kbps  -0.267577  2.993494e-42
# instantaneous_output_kbps -0.266275  7.659617e-42
# allocator_rss_bytes        0.128700  1.056417e-10

# %%
# cluster 별 knob들의 상관계수 합  
numerical_result = pd.DataFrame(index = numerical_var)

cluster_list = [cluster0, cluster1, cluster2, cluster3]

for idx, cluster in enumerate(cluster_list):
    cluster_val = []
    for knob in numerical_var:
        df = cal_spearmanr(subTotal_knobs_T[knob], total_internal_T.loc[:,cluster])
        cluster_val.append(df['corr'].abs().sum())

    numerical_result['cluster'+str(idx)] = cluster_val

# %%
numerical_result
# Out:
#                           cluster0  cluster1  cluster2  cluster3
# save0_0                   0.131075  0.089273  0.087590  0.029786
# save0_1                   0.119660  0.148474  0.047737  0.054440
# save1_0                   0.120897  0.132394  0.062789  0.105810
# save1_1                   0.107582  0.087805  0.081727  0.042945
# save2_0                   0.067284  0.175357  0.083118  0.019064
# save2_1                   0.140120  0.222992  0.050866  0.016158
# maxmemory                 0.052251  1.805280  0.027295  0.007078
# maxmemory-samples         0.037957  0.183298  0.065315  0.014346
# hash-max-ziplist-entries  0.130086  0.068355  0.058503  0.054297
# hash-max-ziplist-value    0.096841  0.121044  0.038630  0.085916
# hz                        0.469969  1.207873  1.145634  0.157267

# %% [markdown]
# ---

# %% [markdown]
# ## Activedefrag 없는 knob들
# * subTotal_knobs_Active
# * total_internal_Active
# active인거는 신경 안써도 된다.
# ### numericalActive_var

# %%
numericalActive_var
# Out:
# ['save0_0',
#  'save0_1',
#  'save1_0',
#  'save1_1',
#  'save2_0',
#  'save2_1',
#  'active-defrag-threshold-lower',
#  'active-defrag-threshold-upper',
#  'active-defrag-cycle-min',
#  'active-defrag-cycle-max',
#  'maxmemory',
#  'maxmemory-samples',
#  'hash-max-ziplist-entries',
#  'hash-max-ziplist-value',
#  'hz']

# %%
extract_pvalue_knob(numericalActive_var, subTotal_knobs_Active,total_internal_Active)
# Out:
# ###save0_0###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
#         corr   p-value
# hz  0.037937  0.047294
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###save0_1###
# pearson
#                         corr   p-value
# lru_clock           0.059351  0.035746
# rdb_last_save_time  0.059352  0.035743
#
# kendalltau
#                            corr   p-value
# used_memory_rss       -0.044470  0.030427
# used_memory_rss_human -0.047318  0.027262
# lru_clock              0.040269  0.042872
# rdb_last_save_time     0.040269  0.042872
#
# spearman
#                            corr   p-value
# used_memory_rss       -0.060946  0.031056
# used_memory_rss_human -0.062604  0.026751
# lru_clock              0.057114  0.043329
# rdb_last_save_time     0.057114  0.043329
#
# ###save1_0###
# pearson
#                         corr   p-value
# lru_clock          -0.070523  0.012561
# rdb_last_save_time -0.070522  0.012563
# used_cpu_sys       -0.061330  0.030011
#
# kendalltau
#                         corr   p-value
# lru_clock          -0.048397  0.010411
# rdb_last_save_time -0.048397  0.010411
#
# spearman
#                         corr   p-value
# lru_clock          -0.072940  0.009831
# rdb_last_save_time -0.072940  0.009831
# used_cpu_sys       -0.056063  0.047337
#
# ###save1_1###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###save2_0###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###save2_1###
# pearson
#                corr   p-value
# maxmemory  0.066207  0.019136
#
# kendalltau
#                      corr   p-value
# maxmemory        0.044858  0.020323
# maxmemory_human  0.040901  0.034372
#
# spearman
#                      corr   p-value
# maxmemory        0.065691  0.020095
# maxmemory_human  0.059903  0.034058
#
# ###active-defrag-threshold-lower###
# pearson
#                          corr   p-value
# allocator_resident   0.055844  0.048207
# allocator_rss_ratio  0.057253  0.042821
# allocator_rss_bytes  0.056016  0.047520
#
# kendalltau
#                         corr  p-value
# rss_overhead_ratio -0.051988  0.02251
#
# spearman
#                         corr   p-value
# rss_overhead_ratio -0.064179  0.023149
#
# ###active-defrag-threshold-upper###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###active-defrag-cycle-min###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###active-defrag-cycle-max###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###maxmemory###
# pearson
#                      corr       p-value
# maxmemory        1.000000  0.000000e+00
# maxmemory_human -0.380639  1.931664e-44
#
# kendalltau
#                             corr   p-value
# maxmemory               1.000000  0.000000
# maxmemory_human         0.792626  0.000000
# total_net_output_bytes -0.047085  0.044166
#
# spearman
#                             corr        p-value
# maxmemory               1.000000   0.000000e+00
# maxmemory_human         0.703904  6.367371e-188
# total_net_output_bytes -0.056817   4.442978e-02
#
# ###maxmemory-samples###
# pearson
#                             corr   p-value
# total_net_output_bytes  0.069112  0.014448
#
# kendalltau
#                             corr   p-value
# maxmemory_human         0.042440  0.044972
# total_net_output_bytes  0.062424  0.012558
#
# spearman
#                             corr   p-value
# maxmemory_human         0.057141  0.043230
# total_net_output_bytes  0.070684  0.012361
#
# ###hash-max-ziplist-entries###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###hash-max-ziplist-value###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###hz###
# pearson
#                                corr       p-value
# hz                         1.000000  0.000000e+00
# used_cpu_sys               0.060589  3.205746e-02
# allocator_allocated       -0.122050  1.487947e-05
# allocator_active          -0.127330  6.204284e-06
# allocator_frag_bytes      -0.088143  1.797683e-03
# instantaneous_ops_per_sec -0.252349  1.220592e-19
# instantaneous_input_kbps  -0.252349  1.220603e-19
# instantaneous_output_kbps -0.250973  1.947886e-19
#
# kendalltau
#                                corr       p-value
# used_memory_rss           -0.088107  8.022528e-06
# used_memory_rss_human     -0.094402  4.525952e-06
# rss_overhead_bytes        -0.060608  1.931699e-03
# mem_fragmentation_bytes    0.056374  3.685414e-03
# hz                         1.000000  0.000000e+00
# used_cpu_sys               0.043038  2.425255e-02
# allocator_allocated       -0.120934  6.723936e-10
# allocator_active          -0.113975  3.149843e-07
# instantaneous_ops_per_sec -0.196044  1.037612e-24
# instantaneous_input_kbps  -0.196038  1.039801e-24
# instantaneous_output_kbps -0.195050  1.778145e-24
# allocator_rss_bytes        0.080270  1.789774e-04
#
# spearman
#                                corr       p-value
# used_memory_rss           -0.122324  1.423230e-05
# used_memory_rss_human     -0.126797  6.787826e-06
# rss_overhead_bytes        -0.085448  2.478463e-03
# mem_fragmentation_bytes    0.085975  2.329010e-03
# hz                         1.000000  0.000000e+00
# used_cpu_sys               0.063898  2.375975e-02
# allocator_allocated       -0.168144  2.146882e-09
# allocator_active          -0.147241  1.665293e-07
# instantaneous_ops_per_sec -0.287529  2.941980e-25
# instantaneous_input_kbps  -0.287526  2.944674e-25
# instantaneous_output_kbps -0.286279  4.815558e-25
# allocator_rss_bytes        0.106733  1.545483e-04

# %% [markdown]
# ## other knob
# * subTotal_knobs_NoActive
# * total_internal_NoActive
# active인거는 신경 안써도 된다.
# ### numericalNoActive_var

# %%
numericalNoActive_var
# Out:
# ['save0_0',
#  'save0_1',
#  'save1_0',
#  'save1_1',
#  'save2_0',
#  'save2_1',
#  'maxmemory',
#  'maxmemory-samples',
#  'hash-max-ziplist-entries',
#  'hash-max-ziplist-value',
#  'hz']

# %%
extract_pvalue_knob(numericalNoActive_var, subTotal_knobs_NoActive,total_internal_NoActive)
# Out:
# ###save0_0###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###save0_1###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###save1_0###
# pearson
#                          corr   p-value
# lru_clock            0.058587  0.038509
# rdb_last_save_time   0.058689  0.038169
# allocator_resident   0.059750  0.034810
# allocator_rss_ratio  0.058408  0.039104
# allocator_rss_bytes  0.059935  0.034250
#
# kendalltau
#                              corr   p-value
# mem_fragmentation_ratio  0.051463  0.025128
# lru_clock                0.039195  0.038311
# rdb_last_save_time       0.039195  0.038311
# allocator_resident       0.053478  0.014550
# allocator_rss_ratio      0.046319  0.045418
# allocator_rss_bytes      0.047804  0.024630
#
# spearman
#                              corr   p-value
# mem_fragmentation_ratio  0.063545  0.024776
# lru_clock                0.058835  0.037692
# rdb_last_save_time       0.058835  0.037692
# allocator_resident       0.068841  0.014999
# allocator_rss_ratio      0.056679  0.045294
# allocator_rss_bytes      0.062296  0.027761
#
# ###save1_1###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###save2_0###
# pearson
#                      corr   p-value
# maxmemory_human  0.071032  0.012073
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###save2_1###
# pearson
#                              corr   p-value
# used_memory_rss         -0.069387  0.014216
# used_memory_rss_human   -0.069410  0.014184
# mem_fragmentation_ratio -0.071462  0.011562
# mem_fragmentation_bytes -0.068305  0.015803
# maxmemory_human          0.057570  0.042008
#
# kendalltau
#                            corr   p-value
# used_memory_rss       -0.047849  0.014383
# used_memory_rss_human -0.044016  0.031150
# rss_overhead_bytes    -0.048128  0.012788
#
# spearman
#                            corr   p-value
# used_memory_rss       -0.068846  0.014992
# used_memory_rss_human -0.060026  0.033979
# rss_overhead_bytes    -0.069295  0.014347
#
# ###maxmemory###
# pearson
#                      corr       p-value
# maxmemory        1.000000  0.000000e+00
# maxmemory_human -0.388349  3.398682e-46
#
# kendalltau
#                      corr  p-value
# maxmemory        1.000000      0.0
# maxmemory_human  0.782955      0.0
#
# spearman
#                      corr        p-value
# maxmemory        1.000000   0.000000e+00
# maxmemory_human  0.690089  3.490625e-177
#
# ###maxmemory-samples###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# spearman
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###hash-max-ziplist-entries###
# pearson
#                              corr   p-value
# mem_fragmentation_ratio  0.058103  0.040142
#
# kendalltau
#                              corr   p-value
# rss_overhead_ratio       0.047895  0.032640
# rss_overhead_bytes       0.037978  0.049666
# mem_fragmentation_ratio  0.047077  0.040455
#
# spearman
#                              corr   p-value
# rss_overhead_ratio       0.060856  0.031579
# rss_overhead_bytes       0.057869  0.040952
# mem_fragmentation_ratio  0.058171  0.039908
#
# ###hash-max-ziplist-value###
# pearson
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# kendalltau
#                         corr   p-value
# rss_overhead_bytes -0.044894  0.020458
#
# spearman
#                         corr   p-value
# rss_overhead_bytes -0.065677  0.020322
#
# ###hz###
# pearson
#                                corr       p-value
# used_memory_rss           -0.061787  2.906186e-02
# used_memory_rss_human     -0.061598  2.955754e-02
# rss_overhead_ratio        -0.079128  5.158921e-03
# rss_overhead_bytes        -0.080882  4.248020e-03
# mem_fragmentation_ratio   -0.056496  4.599648e-02
# hz                         1.000000  0.000000e+00
# allocator_allocated       -0.269775  2.978826e-22
# allocator_active          -0.263758  2.623090e-21
# allocator_frag_bytes      -0.110932  8.598202e-05
# instantaneous_ops_per_sec -0.204899  2.693270e-13
# instantaneous_input_kbps  -0.204899  2.693369e-13
# instantaneous_output_kbps -0.203729  3.695819e-13
# allocator_resident         0.057409  4.258656e-02
# allocator_rss_ratio        0.057280  4.305569e-02
# allocator_rss_bytes        0.066883  1.812416e-02
#
# kendalltau
#                                corr       p-value
# used_memory_rss           -0.102370  2.299089e-07
# used_memory_rss_human     -0.096114  3.329292e-06
# rss_overhead_ratio        -0.053141  1.907765e-02
# rss_overhead_bytes        -0.088353  6.318015e-06
# mem_fragmentation_bytes    0.044346  2.260233e-02
# hz                         1.000000  0.000000e+00
# allocator_allocated       -0.109129  1.702756e-08
# allocator_active          -0.128309  7.805980e-09
# allocator_frag_bytes      -0.038387  4.727623e-02
# instantaneous_ops_per_sec -0.171459  3.182189e-19
# instantaneous_input_kbps  -0.171449  3.194004e-19
# instantaneous_output_kbps -0.170398  5.260410e-19
# allocator_rss_ratio        0.046755  4.576931e-02
# allocator_rss_bytes        0.112698  1.608333e-07
#
# spearman
#                                corr       p-value
# used_memory_rss           -0.141899  4.820113e-07
# used_memory_rss_human     -0.127927  5.804855e-06
# rss_overhead_ratio        -0.065979  1.975139e-02
# rss_overhead_bytes        -0.124587  1.014361e-05
# mem_fragmentation_bytes    0.069352  1.426560e-02
# hz                         1.000000  0.000000e+00
# allocator_allocated       -0.158105  1.964202e-08
# allocator_active          -0.164482  5.075089e-09
# allocator_frag_bytes      -0.058729  3.803769e-02
# instantaneous_ops_per_sec -0.246418  1.018581e-18
# instantaneous_input_kbps  -0.246413  1.020180e-18
# instantaneous_output_kbps -0.245002  1.624919e-18
# allocator_rss_ratio        0.056557  4.576002e-02
# allocator_rss_bytes        0.148978  1.242012e-07

# %% [markdown]
# ---

# %% [markdown]
# ## pointbiserialr 분석

# %%
# pointbiserialr
## yes,no 데이터와 연속형 데이터 상관분석
def cal_pointbiserialr(knobs, internal_df):
    df = pd.DataFrame(columns = ['corr', 'p-value'])
    for internal in internal_df:
        result = pointbiserialr(knobs, internal_df[internal])
        df.loc[internal] = [result[0], result[1]]
    return df

# knob 하나별로 3가지 상관분석 수행
def extract_pvalue(knobs, internal_df):
    print('pointbierialr')
    df = cal_pointbiserialr(knobs, internal_df)
    is_pvalue = df['p-value'] <= 0.05
    print(df[is_pvalue])
    print()


# knob 리스트 각각 별로 extract_pvalue 수행
def extract_pvalue_knob_point(knob_list, subTotal_knobs, total_internal):
    for knob in knob_list:
        print('###{}###'.format(knob))
        extract_pvalue(subTotal_knobs[knob], total_internal)

# %% [markdown]
# ## other knob(activedefrag 제외)
# * subTotal_knobs_T
# * total_internal_T
#
# ### boolean_var

# %%
boolean_var
# Out:
# ['rdbcompression',
#  'rdbchecksum',
#  'rdb-save-incremental-fsync',
#  'lazyfree-lazy-eviction',
#  'lazyfree-lazy-expire',
#  'lazyfree-lazy-server-del',
#  'activerehashing',
#  'dynamic-hz']

# %%
#  yes, no -> 1, 0으로 변경
subTotal_knobs_T_bool = subTotal_knobs_T[boolean_var]  ## boolean 변수 df 추출
subTotal_knobs_T_point = subTotal_knobs_T_bool.replace(['yes', 'no'], [1,0])  ## 1, 0 변경

# %%
extract_pvalue_knob_point(boolean_var, subTotal_knobs_T_point, total_internal_T)
# Out:
# ###rdbcompression###
# pointbierialr
#                             corr   p-value
# total_net_output_bytes -0.056501  0.004715
#
# ###rdbchecksum###
# pointbierialr
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###rdb-save-incremental-fsync###
# pointbierialr
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###lazyfree-lazy-eviction###
# pointbierialr
#                          corr   p-value
# rss_overhead_ratio  -0.046519  0.020017
# rss_overhead_bytes  -0.048922  0.014431
# allocator_resident   0.043003  0.031551
# allocator_rss_ratio  0.043123  0.031080
# allocator_rss_bytes  0.043044  0.031389
#
# ###lazyfree-lazy-expire###
# pointbierialr
# Empty DataFrame
# Columns: [corr, p-value]
# Index: []
#
# ###lazyfree-lazy-server-del###
# pointbierialr
#         corr   p-value
# hz -0.045644  0.022474
#
# ###activerehashing###
# pointbierialr
#                          corr   p-value
# allocator_allocated -0.044451  0.026248
# allocator_active    -0.040469  0.043047
#
# ###dynamic-hz###
# pointbierialr
#                      corr   p-value
# maxmemory_human -0.044941  0.024637

# %%
# cluster 별 knob들의 상관계수 합
bool_result = pd.DataFrame(index = boolean_var)

cluster_list = [cluster0, cluster1, cluster2, cluster3]

for idx, cluster in enumerate(cluster_list):
    cluster_val = []
    for knob in boolean_var:
        df = cal_pointbiserialr(subTotal_knobs_T_point[knob], total_internal_T.loc[:,cluster])
        cluster_val.append(df['corr'].abs().sum())

    bool_result['cluster'+str(idx)] = cluster_val

# %%
bool_result
# Out:
#                             cluster0  cluster1  cluster2  cluster3
# rdbcompression              0.043045  0.247608  0.132567  0.017334
# rdbchecksum                 0.033166  0.112314  0.049670  0.035439
# rdb-save-incremental-fsync  0.134179  0.094039  0.083578  0.051800
# lazyfree-lazy-eviction      0.186498  0.111021  0.024066  0.129169
# lazyfree-lazy-expire        0.122251  0.127492  0.093513  0.023721
# lazyfree-lazy-server-del    0.076782  0.175183  0.051966  0.071605
# activerehashing             0.131495  0.178660  0.191599  0.079875
# dynamic-hz                  0.089357  0.175908  0.114635  0.082941

# %% [markdown]
# ---

# %%
extract_pvalue_knob(numerical_var, subTotal_knobs_T,total_internal_T)
extract_pvalue_knob(numericalActive_var_new, subTotal_knobs_Active,total_internal_Active)
extract_pvalue_knob_point(boolean_var, subTotal_knobs_T_point, total_internal_T)
