# %% [markdown]
# # 상위 및 하위 throughput 값 비교

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston
import xgboost
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
from lightgbm import LGBMRegressor, plot_importance
import lightgbm as lgb
from lightgbm import LGBMClassifier, LGBMRegressor

# %%
# config data(.csv) -> DataFrame
config_df = pd.read_csv("./data/result_config0.csv", sep=',')

# %%
# external data(.csv) -> DataFrame
external_df = pd.read_csv("./data/external_metrics0.csv", sep=',')
throughput_data = external_df['Gets_KB/sec']

# %%
# 40000~ 50000
config_df_knob.loc[group1]
# Out:
#       save0_0  save0_1  save1_0  save1_1  save2_0  save2_1 rdbcompression  \
# 1662      742        8      101       55       88    11162            yes
# 1795      985        6      149       63       37    10506             no
# 1918      748        4      219       61       66    10702            yes
# 2277      936        1      496       94       49     8855            yes
# 2437      751        8      422       69       56    11629            yes
#
#      rdbchecksum rdb-save-incremental-fsync activedefrag  ...  \
# 1662         yes                         no          yes  ...
# 1795         yes                        yes          yes  ...
# 1918          no                        yes          NaN  ...
# 2277          no                        yes          NaN  ...
# 2437         yes                        yes          NaN  ...
#
#       maxmemory-policy  maxmemory-samples  lazyfree-lazy-eviction  \
# 1662      volatile-lfu                  4                     yes
# 1795      volatile-lfu                  7                     yes
# 1918        noeviction                  6                     yes
# 2277      volatile-lru                  5                      no
# 2437      volatile-ttl                  5                      no
#
#       lazyfree-lazy-expire lazyfree-lazy-server-del hash-max-ziplist-entries  \
# 1662                   yes                       no                      342
# 1795                    no                      yes                      604
# 1918                   yes                       no                      401
# 2277                   yes                      yes                      675
# 2437                   yes                       no                      732
#
#       hash-max-ziplist-value activerehashing  hz dynamic-hz
# 1662                     163              no  30        yes
# 1795                      89              no  12        yes
# 1918                     102              no  17        yes
# 2277                     179             yes  28        yes
# 2437                     255             yes  32         no
#
# [5 rows x 25 columns]

# %%
# 40000~ 50000
config_df_knob.loc[group1]

# %%
# 40000~ 50000
config_df_knob.loc[group1]

# %% [markdown]
# ### config index
# 데이터 프레임 인덱스를 1 더한다.
#
#
# ### 비교 결과
# ( 샘플 생성 중 값, 다시 돌린 값)
# #### 40000대
# * 1795 : config11796 (47520.43, 61211.65)
# * 2437 : config12438 ( 47543.22, 62077.59)
#
# #### 60000대
# * 282 : config10283 (66377.65, 62776.06)
# * 288 : config10289 (66161.63 , 62168.97)

# %%
# 60000~
config_df_knob.loc[group2]
# Out:
#       save0_0  save0_1  save1_0  save1_1  save2_0  save2_1 rdbcompression  \
# 31        791        5      433       71       84    11880            yes
# 280       932        7      279       71       33     9449             no
# 281       952        2      464       62       83    10574            yes
# 282      1073        2      470       37       57     8334            yes
# 285       778        5      326       48       31     8676             no
# 288      1070        5      183       14       42    11677             no
# 2007      784        7      151       55       76    10844            yes
# 2010     1029        6      301       99       39     8505            yes
# 2036      708        8      469       12       34    10671             no
# 2051      753        7      116       48       47    11530             no
#
#      rdbchecksum rdb-save-incremental-fsync activedefrag  ...  \
# 31           yes                        yes          yes  ...
# 280           no                         no          yes  ...
# 281          yes                        yes          yes  ...
# 282           no                        yes          NaN  ...
# 285           no                        yes          NaN  ...
# 288          yes                         no          NaN  ...
# 2007          no                         no          NaN  ...
# 2010          no                         no          yes  ...
# 2036          no                        yes          NaN  ...
# 2051         yes                         no          NaN  ...
#
#       maxmemory-policy  maxmemory-samples  lazyfree-lazy-eviction  \
# 31          noeviction                  6                     yes
# 280         noeviction                  3                      no
# 281        allkeys-lfu                  5                      no
# 282    volatile-random                  3                     yes
# 285    volatile-random                  5                      no
# 288       volatile-ttl                  7                      no
# 2007   volatile-random                  7                      no
# 2010       allkeys-lru                  3                      no
# 2036      volatile-lru                  6                     yes
# 2051      volatile-ttl                  6                     yes
#
#       lazyfree-lazy-expire lazyfree-lazy-server-del hash-max-ziplist-entries  \
# 31                      no                       no                      567
# 280                     no                       no                      518
# 281                    yes                       no                      338
# 282                     no                       no                      652
# 285                     no                       no                      739
# 288                    yes                       no                      617
# 2007                   yes                       no                      558
# 2010                    no                      yes                      307
# 2036                    no                       no                      694
# 2051                    no                       no                      383
#
#       hash-max-ziplist-value activerehashing  hz dynamic-hz
# 31                        56             yes  24        yes
# 280                       46             yes  39        yes
# 281                       29              no   6        yes
# 282                      128             yes   9         no
# 285                      208             yes  32         no
# 288                      141              no  32         no
# 2007                     104              no  34         no
# 2010                     253             yes  39        yes
# 2036                      47             yes  22         no
# 2051                     147              no  40        yes
#
# [10 rows x 25 columns]

# %% [markdown]
# ### 집중 분석
#
# #### 1795 : config11796 (47520.43, 61211.65)
#
# #### 282 : config10283 (66377.65, 62776.06)
#
#
# * 61952.41
# * 61781.22

# %%
config11796_list = [
     61405.20, 
     62037.21,
     62790.46,
     50882.75,
     53117.00,
     63123.75,
     60953.72,
     62310.07,
     62165.16,
     63028.86,
     62071.70,
     62899.19,
     62422.44,
     59699.33,
     62539.54,
     61293.85,
     61547.00,
     60698.41,
     62001.42,
     62345.61,
     62083.89,
     62992.31,
     61465.27,
     61179.99,
     61081.99,
     61086.75,
     61966.45,
     63043.77,
     62400.26,
     61998.99
    ,59023.89
    ,62360.05
    , 62238.70
    , 62146.73
    , 62485.80 
    , 60601.26
    , 62535.97
    , 62095.70
    ,  63944.87 
    , 61297.06
    , 61059.83
    , 61398.15
    , 62541.83 
    , 
]

config10283_list = [
     63327.70,
     62611.30,
     60831.53,
     61640.79,
     59951.08,
     61889.27,
     62298.92,
     63488.50,
     63218.48,
    61695.35 ,
    61015.91,
    63282.41 ,
    62270.53 ,
    62643.45 ,
     62529.00  ,
    61736.26,
    61331.97,
    60819.36 ,
    60470.38 ,
    62398.65,
    61017.92,
    62090.46,
    62045.09,
    62688.61 ,
    62248.64,
    60936.61 ,
    61744.44 ,
     61407.19 ,
    62951.79,
    60677.40,
    61395.38 ,
    62291.67,
    61273.25,
    62131.52,
    61120.18,
    62290.26,
    59415.19 ,
     61982.85 ,
    62487.80,
     62074.21,
    61563.17,        
    62875.82,
    63095.33 
]

# %%
df_config_hist = pd.DataFrame(config11796_list, columns=["config11796"])
df_config_hist['config10283'] = config10283_list
df_config_hist['config_gp'] = config_gp
df_config_hist['config_t0'] = config_t0
df_config_hist['config_t1'] = config_t1
df_config_hist['config_gp1'] = config_gp1


df_config_hist.head()
# Out:
#    config11796  config10283  config_gp  config_t0  config_t1  config_gp1
# 0     61405.20     63327.70   63461.96   60679.38   60798.83    61675.31
# 1     62037.21     62611.30   61888.84   62452.81   62067.84    62540.02
# 2     62790.46     60831.53   64003.96   62932.05   63618.54    61947.75
# 3     50882.75     61640.79   63283.22   63905.71   62803.20    62767.91
# 4     53117.00     59951.08   63023.32   61936.38   62191.44    61187.31

# %%
import seaborn as sns
sns.boxplot(x = "config11796",data = df_config_hist )
plt.show()

# %%
sns.boxplot(x = "config10283",data = df_config_hist )
plt.show()

# %%
sns.boxplot(x = "config_gp",data = df_config_hist )
plt.show()

# %%
sns.boxplot(x = "config_t0",data = df_config_hist )
plt.show()

# %%
sns.set(font_scale=1)
sns.boxplot(x = "config_t1",data = df_config_hist )
plt.show()

# %%
sns.boxplot(x = "config_gp1",data = df_config_hist )
plt.show()

# %%
df_config_hist2 = df_config_hist.iloc[:,4:]

# %%
df_config_hist2.hist(figsize=(10,5), bins=15)
# Out:
# array([[<AxesSubplot:title={'center':'config_t1'}>,
#         <AxesSubplot:title={'center':'config_gp1'}>]], dtype=object)

# %%
df_config_hist3 = df_config_hist.iloc[:,:2]
df_config_hist3.hist(figsize=(10,5), bins=15)
# Out:
# array([[<AxesSubplot:title={'center':'config11796'}>,
#         <AxesSubplot:title={'center':'config10283'}>]], dtype=object)

# %%
print(df_config_hist[['config11796']].mean())
print(df_config_hist[['config10283']].mean())
print(df_config_hist[['config_gp']].mean())
print(df_config_hist[['config_t0']].mean())
print(df_config_hist[['config_t1']].mean())
print(df_config_hist[['config_gp1']].mean())
# Out:
# config11796    61450.283256
# dtype: float64
# config10283    61778.736977
# dtype: float64
# config_gp    62747.787209
# dtype: float64
# config_t0    62603.914884
# dtype: float64
# config_t1    62237.830465
# dtype: float64
# config_gp1    61883.316744
# dtype: float64
