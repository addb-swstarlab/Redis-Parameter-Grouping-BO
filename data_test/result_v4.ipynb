# %% [markdown]
# # throughput 결과 비교

# %%
import pandas as pd
import os
import numpy as np
from scipy import stats
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
import math
import numpy as np
from numpy.random import randn
from statsmodels.stats.weightstats import ztest

# %%
# 경로 내 파일 확인
os.listdir('./result_data')
# Out:
# ['gp_rdb_external_4_v1.csv',
#  'gp_rdb_external_4_v2.csv',
#  '.DS_Store',
#  'gp_rdb_internal_4_v2.csv',
#  'gp_rdb_internal_4_v1.csv',
#  'gp_aof_external_4_v2.csv',
#  'gp_T_rdb_external_4.csv',
#  'gp_aof_external_4_v1.csv',
#  'gp_rdb_external_4_v21.csv',
#  'gp_aof_internal_4_v1.csv',
#  'gp_aof_internal_4_v2.csv',
#  'gp_rdb_external_4_test.csv',
#  'gp_rdb_external_4_v11.csv',
#  '.ipynb_checkpoints',
#  'check.csv',
#  'default_rdb_external_4.csv',
#  'default_aof_external_4.csv',
#  'gp_aof_external_4_v11.csv']

# %%
# 평균
def mean_ten_list(data):
    mean_dict = {}
    len_data = len(data)
    count = len_data - 10+1
    for i in range(count):
        print(i, end=' ')
        print(data[i:i+10].mean())
        mean_dict[i] = data[i:i+10]
    return mean_dict

# %% [markdown]
# 워크로드 두개
# * 1:1
# * 1:0
#
# aof, rdb
# * aof
# * rdb
#
# 비교대상 3개
# * default
# * gp -> 8
# * gp_T -> 8
#
# 디폴트
# * default_[rdb, aof]_external_4

# %%
# gp_T_rdb_external_4.csv [전체 gp]

# rdb 1:1 internal -> configfile 확인용
gp_rdb_internal_4_v1 = pd.read_csv('./result_data/gp_rdb_internal_4_v1.csv', sep=',')
gp_rdb_internal_4_v1_T = gp_rdb_internal_4_v1[240:]

# rdb 1:1 external  30개씩
gp_rdb_external_4_v1 = pd.read_csv('./result_data/gp_rdb_external_4_v1.csv', sep=',')
gp_rdb_external_4_v1_th = gp_rdb_external_4_v1['Gets_KB/sec'][0:240].values  # throughput 값 추출

# rdb 1:1 external  30개씩
gp_rdb_external_4_T_v1 = pd.read_csv('./result_data/gp_rdb_external_4_v1.csv', sep=',')
gp_rdb_external_4_v1_T_th = gp_rdb_external_4_v1['Gets_KB/sec'][240:].values  # throughput 값 추출

# rdb 1:1 default  30개씩  90개까지!!
default_rdb_external_4 = pd.read_csv('./result_data/default_rdb_external_4.csv', sep=',')  
default_rdb_external_4_th_Total = default_rdb_external_4['Gets_KB/sec'].values # throughput 값 추출
default_rdb_external_4_th = default_rdb_external_4_th_Total[:90]

# %%
for i in range(14):
    print('###{}###'.format(i))
    x1 = gp_rdb_external_4_v1_th[i+30:i+10+30]
    x2 = gp_rdb_external_4_v1_T_th[18:28]
    print('분퓨별 파라미터',x1.mean())
    print('전체 파라미터',x2.mean())
    print(sp.stats.ttest_ind(x1, x2, equal_var=True, alternative='greater'))
# Out:
# ###0###
# 분퓨별 파라미터 56282.203
# 전체 파라미터 56012.24600000001
# Ttest_indResult(statistic=0.146798825236428, pvalue=0.44246124477480714)
# ###1###
# 분퓨별 파라미터 56480.825
# 전체 파라미터 56012.24600000001
# Ttest_indResult(statistic=0.2530891635071234, pvalue=0.40153360648357805)
# ###2###
# 분퓨별 파라미터 55777.451
# 전체 파라미터 56012.24600000001
# Ttest_indResult(statistic=-0.12883454342982786, pvalue=0.5505414000587352)
# ###3###
# 분퓨별 파라미터 56217.587
# 전체 파라미터 56012.24600000001
# Ttest_indResult(statistic=0.11437071375672433, pvalue=0.45510501328761327)
# ###4###
# 분퓨별 파라미터 56031.826
# 전체 파라미터 56012.24600000001
# Ttest_indResult(statistic=0.011462730966131889, pvalue=0.49549017852761645)
# ###5###
# 분퓨별 파라미터 56312.275
# 전체 파라미터 56012.24600000001
# Ttest_indResult(statistic=0.17794122313397398, pvalue=0.4303781854840308)
# ###6###
# 분퓨별 파라미터 56209.067
# 전체 파라미터 56012.24600000001
# Ttest_indResult(statistic=0.11766245265646114, pvalue=0.4538190680520838)
# ###7###
# 분퓨별 파라미터 56140.288
# ...

# %%
x1.mean()
# Out:
# 58096.62733333334

# %%
list(gp_rdb_internal_4_v1_T['config_file'][90:105])
# Out:
# ['/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso_T.conf',
# ...

# %%
list(gp_rdb_internal_4_v1['config_file'][180:210])
# Out:
# ['/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
#  '/home/swredis/redis-sample-generation/configfiletest/rdb1/config_rdb1_lasso.conf',
# ...

# %% [markdown]
# ## RDB1 (1:1)

# %%
for i in range(8):
    x1 = gp_rdb_external_4_v1_th[0+i*30:30+i*30]
    x2 = gp_rdb_external_4_v1_T_th[0+i*30:30+i*30]
#     print(x1.mean())
#     print(x2.mean())

    print(sp.stats.ttest_ind(x1, x2, equal_var=True, alternative='greater'))
# Out:
# Ttest_indResult(statistic=0.9768487207292167, pvalue=0.16635047799180097)
# Ttest_indResult(statistic=-1.441339947975168, pvalue=0.9225668923356065)
# Ttest_indResult(statistic=0.7904757495433828, pvalue=0.21623513861860344)
# Ttest_indResult(statistic=0.8524789689199147, pvalue=0.1987274355978072)
# Ttest_indResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
# x1 = gp_rdb1_lightgbm_mean_ten[4]
# x2 = default_rdb1_mean_ten[0]
# stats.ranksums(x1, x2, alternative='greater')

# %%
# for j in range(30):
#     for i in range(20):
#         x1 = gp_rdb1_lightgbm_mean_ten[i]
#         x2 = default_rdb1_mean_ten[j]
#         print(stats.ranksums(x1, x2, alternative='greater'))

# %% [markdown]
# rdb1:1
#
# default_rdb_external_4_th (90)  10
#
# gp_rdb_external_4_v1_th (240)  8개 모델별로 10개
#
# gp_rdb_external_4_v1_T_th (240)  8개 모델별로 10개

# %%
default_rdb1_mean_ten = mean_ten_list(default_rdb_external_4_th)  ## 0
# Out:
# 0 57467.329000000005
# 1 58244.219
# 2 57693.363
# 3 57015.605
# 4 56920.344
# 5 56282.439
# 6 56466.744000000006
# 7 58164.35399999999
# 8 58344.01399999999
# 9 57912.426
# 10 57150.998
# 11 56705.91199999999
# 12 56380.751000000004
# 13 56149.48
# 14 55422.96699999999
# 15 54711.105
# 16 55198.090000000004
# 17 54963.87999999999
# 18 54178.56499999999
# 19 54298.928
# 20 55511.23100000001
# 21 56522.30500000001
# 22 57347.971999999994
# 23 58233.39600000001
# 24 58794.286
# 25 59043.797000000006
# 26 58987.30299999999
# 27 59018.80099999999
# 28 59710.221999999994
# 29 59816.07200000001
# 30 60874.427
# 31 59838.599
# 32 60030.102
# 33 59658.56299999999
# 34 60234.06799999999
# 35 61428.382
# 36 61353.757
# 37 60792.337
# 38 60066.873999999996
# 39 60507.36699999999
# 40 59405.448
# 41 60260.795
# 42 59740.498
# 43 59415.342000000004
# 44 58826.16399999999
# 45 58204.226
# 46 56996.143000000004
# 47 54432.998
# 48 55161.284999999996
# 49 55161.01900000001
# 50 56214.109
# ...

# %%
print('lightgbm')
gp_rdb1_lightgbm_mean_ten = mean_ten_list(gp_rdb_external_4_v1_th[0:30])  ## 0
print('xgb')
gp_rdb1_xgb_mean_ten = mean_ten_list(gp_rdb_external_4_v1_th[30:60])  ## 18
print('dt')
gp_rdb1_dt_mean_ten = mean_ten_list(gp_rdb_external_4_v1_th[60:90])  ##1
print('gbm')
gp_rdb1_gbm_mean_ten = mean_ten_list(gp_rdb_external_4_v1_th[90:120])  ##19
print('rf')
gp_rdb1_rf_mean_ten = mean_ten_list(gp_rdb_external_4_v1_th[120:150])  ## 10
print('ridge')
gp_rdb1_ridge_mean_ten = mean_ten_list(gp_rdb_external_4_v1_th[150:180])  ## 9
print('lasso')
gp_rdb1_ridge_mean_ten = mean_ten_list(gp_rdb_external_4_v1_th[180:210])  ## 9
print('lr')  
gp_rdb1_lr_mean_ten = mean_ten_list(gp_rdb_external_4_v1_th[210:240])  ##  1
# Out:
# lightgbm
# 0 60213.48099999999
# 1 59315.93000000001
# 2 59397.425
# 3 57835.574
# 4 57287.279
# 5 58052.257000000005
# 6 58451.464
# 7 57294.10599999999
# 8 57607.746
# 9 57913.255000000005
# 10 57338.00399999999
# 11 57046.162
# 12 57858.406
# 13 58766.526
# 14 59587.388
# 15 59131.96499999999
# 16 59323.507
# 17 60334.19299999999
# 18 60219.22900000001
# 19 60111.94600000001
# 20 60360.914000000004
# xgb
# 0 56282.203
# 1 56480.825
# 2 55777.451
# 3 56217.587
# 4 56031.826
# 5 56312.275
# 6 56209.067
# 7 56140.288
# 8 56457.134
# 9 54711.926
# 10 54383.056000000004
# 11 55131.384999999995
# 12 55752.251000000004
# 13 55870.933999999994
# 14 55684.4
# 15 56580.688
# 16 57264.234
# 17 57985.634
# 18 58518.614
# 19 60100.9
# 20 61443.755000000005
# dt
# 0 61835.605
# 1 60485.989
# 2 60748.667
# 3 59979.366
# 4 59870.070999999996
# 5 59300.569
# 6 59591.93199999999
# 7 59577.496
# 8 59800.825
# 9 59107.90700000001
# 10 57850.22000000001
# 11 58306.016
# 12 58196.996
# 13 58213.678
# ...

# %%
print('lightgbm')
gp_rdb1_lightgbm_mean_ten = mean_ten_list(gp_rdb_external_4_v1_T_th[0:15])  ## 0
print('xgb')
gp_rdb1_xgb_mean_ten = mean_ten_list(gp_rdb_external_4_v1_T_th[15:30])  ## 18
print('dt')
gp_rdb1_dt_mean_ten = mean_ten_list(gp_rdb_external_4_v1_T_th[30:45])  ##1
print('gbm')
gp_rdb1_gbm_mean_ten = mean_ten_list(gp_rdb_external_4_v1_T_th[45:60])  ##19
print('rf')
gp_rdb1_rf_mean_ten = mean_ten_list(gp_rdb_external_4_v1_T_th[60:75])  ## 10
print('ridge')
gp_rdb1_ridge_mean_ten = mean_ten_list(gp_rdb_external_4_v1_T_th[75:90])  ## 9
print('lasso')
gp_rdb1_ridge_mean_ten = mean_ten_list(gp_rdb_external_4_v1_T_th[90:105])  ## 9
print('lr')  
gp_rdb1_lr_mean_ten = mean_ten_list(gp_rdb_external_4_v1_T_th[105:120])  ##  1
# Out:
# lightgbm
# 0 59641.50600000001
# 1 59465.159
# 2 59010.373999999996
# 3 59352.063
# 4 59194.094999999994
# 5 59143.214
# xgb
# 0 58003.39200000001
# 1 57657.45
# 2 56705.134999999995
# 3 56012.24600000001
# 4 55901.43600000001
# 5 55628.530000000006
# dt
# 0 58348.412999999986
# 1 59185.987
# 2 58895.253000000004
# 3 59325.863
# 4 58905.433000000005
# 5 60156.91800000002
# gbm
# 0 58039.027
# 1 58444.518
# 2 59134.431
# 3 59314.272
# 4 59012.54299999999
# 5 58612.058999999994
# rf
# 0 57668.90499999999
# 1 56968.12200000001
# 2 58068.01899999999
# 3 56487.768
# 4 57297.84300000001
# 5 57299.455
# ridge
# 0 56955.234
# 1 56113.3
# 2 56326.225
# 3 56645.628000000004
# 4 56605.563
# 5 57009.93199999999
# lasso
# 0 55759.522
# 1 56639.877
# 2 56519.403000000006
# 3 56236.662
# 4 57705.52
# 5 58024.524
# lr
# 0 57874.71800000001
# 1 58930.324
# 2 59378.719000000005
# 3 58373.653000000006
# 4 57726.433000000005
# 5 58638.65

# %% [markdown]
# ---

# %% [markdown]
# ## RDB 1:0

# %%
first = 0
for i in range(8):
    x1 = gp_rdb_external_4_v21_th[first+i*30:10+i*30]
    x2 = gp_rdb_external_4_v21_T_th[first+i*30:10+i*30]
#     print(x1.mean())
#     print(x2.mean())

    print(sp.stats.ttest_ind(x1, x2, equal_var=True, alternative='greater'))
# Out:
# Ttest_indResult(statistic=0.6334852236690953, pvalue=0.26719203692376564)
# Ttest_indResult(statistic=3.19786117904876, pvalue=0.002492938112112747)
# Ttest_indResult(statistic=0.1398232383906084, pvalue=0.4451761599812126)
# Ttest_indResult(statistic=1.2268728379481508, pvalue=0.11783833165405262)
# Ttest_indResult(statistic=-0.9611362715774479, pvalue=0.8253909472760506)
# Ttest_indResult(statistic=-3.0486769788444668, pvalue=0.9965438172931429)
# Ttest_indResult(statistic=0.05447470226675413, pvalue=0.47857851934923884)
# Ttest_indResult(statistic=0.2094829483277626, pvalue=0.41821194061857203)

# %%
# rdb1:0 
# default_rdb_external_4_th (90)  10
# gp_rdb_external_4_v2_th (240)  8개 모델별로 10개 
# gp_rdb_external_4_v2_T_th (240)  8개 모델별로 10개

# %%
# gp_T_rdb_external_4.csv [전체 gp]

# # rdb 1:0 internal -> configfile 확인용
# gp_rdb_internal_4_v21 = pd.read_csv('./result_data/gp_rdb_internal_4_v21.csv', sep=',')  # 개별
# gp_rdb_internal_4_v21_T = gp_rdb_internal_4_v21[120:]  # T 

# rdb 1:0 external  15개씩
gp_rdb_external_4_v21 = pd.read_csv('./result_data/gp_rdb_external_4_v21.csv', sep=',')
gp_rdb_external_4_v21_th = gp_rdb_external_4_v21['Gets_KB/sec'][0:240].values  # throughput 값 추출

# rdb 1:0 external  15개씩
gp_rdb_external_4_T_v21 = pd.read_csv('./result_data/gp_rdb_external_4_v21.csv', sep=',')
gp_rdb_external_4_v21_T_th = gp_rdb_external_4_T_v21['Gets_KB/sec'][240:].values  # throughput 값 추출

# rdb 1:0 default  15개씩  90개까지!!
# default_rdb_external_4 = pd.read_csv('./result_data/default_rdb_external_4.csv', sep=',')  
# default_rdb_external_4_th_Total = default_rdb_external_4['Gets_KB/sec'].values # throughput 값 추출
default_rdb2_external_4_th = default_rdb_external_4_th_Total[90:]

# %%
default_rdb2_mean_ten = mean_ten_list(default_rdb2_external_4_th)  ## 0
# Out:
# 0 61132.154
# 1 60637.567
# 2 60621.966
# 3 60162.98300000001
# 4 59675.157999999996
# 5 59324.704999999994
# 6 58707.34199999999
# 7 59853.06799999999
# 8 59069.948
# 9 58884.77300000001
# 10 58563.514
# 11 59047.573
# 12 58085.94099999999
# 13 58112.926
# 14 58991.44099999999
# 15 59063.234
# 16 59604.590000000004
# 17 58627.23400000001
# 18 58800.35900000001
# 19 58512.31799999999
# 20 58016.126000000004
# 21 57505.73100000001
# 22 58303.659
# 23 57626.174
# 24 56881.868
# 25 56612.522
# 26 56615.445999999996
# 27 56486.32000000001
# 28 56650.799
# 29 56323.591
# 30 56370.636
# 31 56153.398
# 32 56395.505000000005
# 33 57016.204000000005
# 34 56627.217000000004
# 35 57234.95
# 36 57621.588
# 37 58349.672999999995
# 38 58776.152
# 39 59142.708
# 40 58919.323
# 41 58493.898
# 42 57755.23999999999
# 43 57391.458000000006
# 44 58147.35800000001
# 45 58018.585
# 46 58493.66499999999
# 47 58481.583000000006
# 48 58123.178
# 49 58289.91000000001
# 50 58433.801
# 51 58997.78300000001
# ...

# %%
print('lightgbm')
gp_rdb2_lightgbm_mean_ten = mean_ten_list(gp_rdb_external_4_v21_th[0:30])  ## 0
print('xgb')
gp_rdb2_xgb_mean_ten = mean_ten_list(gp_rdb_external_4_v21_th[30:60])  ## 18
print('dt')
gp_rdb2_dt_mean_ten = mean_ten_list(gp_rdb_external_4_v21_th[60:90])  ##1
print('gbm')
gp_rdb2_gbm_mean_ten = mean_ten_list(gp_rdb_external_4_v21_th[90:120])  ##19
print('rf')
gp_rdb2_rf_mean_ten = mean_ten_list(gp_rdb_external_4_v21_th[120:150])  ## 10
print('ridge')
gp_rdb2_ridge_mean_ten = mean_ten_list(gp_rdb_external_4_v21_th[150:180])  ## 9
print('lasso')
gp_rdb2_ridge_mean_ten = mean_ten_list(gp_rdb_external_4_v21_th[180:210])  ## 9
print('lr')  
gp_rdb2_lr_mean_ten = mean_ten_list(gp_rdb_external_4_v21_th[210:240])  ##  1
# Out:
# lightgbm
# 0 58651.21499999999
# 1 58677.007
# 2 57696.155000000006
# 3 57452.42899999999
# 4 57324.398
# 5 56417.85799999999
# 6 56954.899
# 7 56401.219000000005
# 8 57716.165
# 9 56517.17799999999
# 10 57354.114
# 11 58460.116
# 12 59059.982
# 13 58011.903000000006
# 14 57035.29400000001
# 15 57722.937
# 16 57084.655000000006
# 17 58583.949
# 18 57461.966
# 19 57297.603
# 20 57170.397
# xgb
# 0 59500.189
# 1 59376.998999999996
# 2 59598.496
# 3 59278.939
# 4 59824.971
# 5 59953.721
# 6 60333.820999999996
# 7 59739.13500000001
# 8 58662.029
# 9 58109.715000000004
# 10 57220.291000000005
# 11 57830.94499999999
# 12 57458.62999999999
# 13 57134.036
# 14 57081.922
# 15 56032.185
# 16 56930.379
# 17 57404.083000000006
# 18 57867.045
# 19 56799.861
# 20 56755.22300000001
# dt
# 0 57471.176
# 1 56116.422
# 2 57360.244000000006
# 3 57922.38999999999
# 4 56229.688
# 5 56898.121999999996
# 6 56540.121
# 7 54903.159
# 8 53725.172
# 9 52444.576
# 10 53089.159
# 11 53721.56
# ...

# %%
print('lightgbm')
gp_rdb2_lightgbm_mean_ten = mean_ten_list(gp_rdb_external_4_v21_T_th[0:30])  ## 0
print('xgb')
gp_rdb2_xgb_mean_ten = mean_ten_list(gp_rdb_external_4_v21_T_th[30:60])  ## 18
print('dt')
gp_rdb2_dt_mean_ten = mean_ten_list(gp_rdb_external_4_v21_T_th[60:90])  ##1
print('gbm')
gp_rdb2_gbm_mean_ten = mean_ten_list(gp_rdb_external_4_v21_T_th[90:120])  ##19
print('rf')
gp_rdb2_rf_mean_ten = mean_ten_list(gp_rdb_external_4_v21_T_th[120:150])  ## 10
print('ridge')
gp_rdb2_ridge_mean_ten = mean_ten_list(gp_rdb_external_4_v21_T_th[150:180])  ## 9
print('lasso')
gp_rdb2_ridge_mean_ten = mean_ten_list(gp_rdb_external_4_v21_T_th[180:210])  ## 9
print('lr')  
gp_rdb2_lr_mean_ten = mean_ten_list(gp_rdb_external_4_v21_T_th[210:240])  ##  1
# Out:
# lightgbm
# 0 57145.25499999999
# 1 57076.594000000005
# 2 56810.827000000005
# 3 56161.907999999996
# 4 57055.248999999996
# 5 55726.225
# 6 56346.695999999996
# 7 56939.67999999999
# 8 57161.03200000001
# 9 56555.348
# 10 56075.66599999999
# 11 56104.652
# 12 57189.641
# 13 57413.65699999999
# 14 56447.43000000001
# 15 57517.562
# 16 57038.616
# 17 57349.240000000005
# 18 57416.956999999995
# 19 57374.98899999999
# 20 56913.429000000004
# xgb
# 0 51921.158
# 1 52203.344
# 2 52561.13700000001
# 3 52584.238
# 4 53263.98300000001
# 5 53768.35400000001
# 6 54038.348
# 7 54447.105
# 8 54664.181
# 9 55525.795999999995
# 10 58062.85400000001
# 11 55672.797
# 12 54304.346999999994
# 13 53478.884
# 14 53740.706000000006
# 15 54892.185
# 16 55775.63300000001
# 17 56734.802
# 18 57184.264
# 19 57952.295999999995
# 20 58073.903999999995
# dt
# 0 57052.926
# 1 57042.90800000001
# 2 57296.42599999999
# 3 56527.11699999999
# 4 55425.329000000005
# 5 54443.324
# 6 53808.79400000001
# 7 53601.564
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## aof 1:1

# %%
for i in range(8):
    x1 = gp_aof_external_4_v11_th[0+i*30:30+i*30]
    x2 = gp_aof_external_4_v11_T_th[0+i*30:30+i*30]
#     print(x1.mean())
#     print(x2.mean())

    print(sp.stats.ttest_ind(x1, x2, equal_var=True, alternative='greater'))
# Out:
# Ttest_indResult(statistic=-0.6003236936141172, pvalue=0.7246854529631128)
# Ttest_indResult(statistic=-0.7109179042195847, pvalue=0.7600078313401147)
# Ttest_indResult(statistic=0.22016062606056575, pvalue=0.4132595774140192)
# Ttest_indResult(statistic=-0.038624961605866606, pvalue=0.5153389779799076)
# Ttest_indResult(statistic=1.1032398600241147, pvalue=0.13723976029487356)
# Ttest_indResult(statistic=-1.0266210777327445, pvalue=0.845569225704084)
# Ttest_indResult(statistic=0.7493214227448425, pvalue=0.22834598601958694)
# Ttest_indResult(statistic=1.051097163554866, pvalue=0.14878686258759263)

# %%
stats.shapiro(gp_aof_external_4_v11_T_th[0:30])
# Out:
# ShapiroResult(statistic=0.7212083339691162, pvalue=3.224125066481065e-06)

# %%
# aof1:1
# default_rdb_external_4_th (90)  10
# gp_rdb_external_4_v2_th (240)  8개 모델별로 10개 
# gp_rdb_external_4_v2_T_th (240)  8개 모델별로 10개

# %%
# aof1:0 
# default_rdb_external_4_th (90)  10
# gp_rdb_external_4_v2_th (240)  8개 모델별로 10개 
# gp_rdb_external_4_v2_T_th (240)  8개 모델별로 10개
# gp_T_rdb_external_4.csv [전체 gp]

# # rdb 1:0 internal -> configfile 확인용
# gp_aof_internal_4_v11 = pd.read_csv('./result_data/gp_aof_internal_4_v11.csv', sep=',')  # 개별
# gp_aof_internal_4_v11_T = gp_aof_internal_4_v11[120:]  # T 

# rdb 1:0 external  15개씩
gp_aof_external_4_v11 = pd.read_csv('./result_data/gp_aof_external_4_v11.csv', sep=',')
gp_aof_external_4_v11_th = gp_aof_external_4_v11['Gets_KB/sec'][0:240].values  # throughput 값 추출

# rdb 1:0 external  15개씩
gp_aof_external_4_T_v11 = pd.read_csv('./result_data/gp_aof_external_4_v11.csv', sep=',')
gp_aof_external_4_v11_T_th = gp_aof_external_4_T_v11['Gets_KB/sec'][120:].values  # throughput 값 추출

# rdb 1:0 default  15개씩  90개까지!!
default_aof_external_4 = pd.read_csv('./result_data/default_aof_external_4.csv', sep=',')  
default_aof_external_4_th_Total = default_aof_external_4['Gets_KB/sec'].values # throughput 값 추출
default_aof2_external_4_th = default_aof_external_4_th_Total[:90]

# %%
default_aof2_mean_ten = mean_ten_list(default_aof2_external_4_th)  ## 0
# Out:
# 0 46638.707
# 1 47274.590000000004
# 2 46668.386000000006
# 3 46765.38799999999
# 4 47224.566
# 5 46942.151
# 6 47467.547999999995
# 7 47424.62999999999
# 8 48131.629
# 9 48245.87999999999
# 10 48602.55
# 11 48265.00199999999
# 12 48467.467
# 13 47994.528999999995
# 14 48322.474
# 15 48360.904
# 16 48534.898
# 17 48423.133
# 18 48262.322
# 19 48164.951
# 20 48058.557
# 21 48122.397000000004
# 22 48026.85799999999
# 23 48335.22499999999
# 24 47788.168999999994
# 25 48392.112
# 26 48551.047999999995
# 27 48930.188
# 28 48756.144
# 29 48447.835999999996
# 30 48068.931
# 31 48104.003000000004
# 32 48004.015999999996
# 33 47063.759999999995
# 34 47564.003
# 35 46954.31999999999
# 36 46879.977
# 37 46522.004
# 38 46363.223
# 39 46680.984
# 40 46818.808000000005
# 41 46894.637
# 42 47141.104
# 43 48134.63999999999
# 44 47843.975
# 45 48335.967
# 46 47992.923
# 47 47932.265999999996
# 48 47777.869999999995
# 49 47631.003
# 50 47589.948
# 51 48095.935000000005
# 52 48026.366
# 53 47899.082
# ...

# %%
print('lightgbm')
gp_aof1_lightgbm_mean_ten = mean_ten_list(gp_aof_external_4_v11_th[0:30])  ## 0
print('xgb')
gp_aof1_xgb_mean_ten = mean_ten_list(gp_aof_external_4_v11_th[30:60])  ## 18
print('dt')
gp_aof1_dt_mean_ten = mean_ten_list(gp_aof_external_4_v11_th[60:90])  ##1
print('gbm')
gp_aof1_gbm_mean_ten = mean_ten_list(gp_aof_external_4_v11_th[90:120])  ##19
print('rf')
gp_aof1_rf_mean_ten = mean_ten_list(gp_aof_external_4_v11_th[120:150])  ## 10
print('ridge')
gp_aof1_ridge_mean_ten = mean_ten_list(gp_aof_external_4_v11_th[150:180])  ## 9
print('lasso')
gp_aof1_ridge_mean_ten = mean_ten_list(gp_aof_external_4_v11_th[180:210])  ## 9
print('lr')  
gp_aof1_lr_mean_ten = mean_ten_list(gp_aof_external_4_v11_th[210:240])  ##  1
# Out:
# lightgbm
# 0 44015.18
# 1 43905.723999999995
# 2 44072.104
# 3 43760.938
# 4 44357.192
# 5 44781.948
# 6 46136.773
# 7 46155.343
# 8 45996.99800000001
# 9 46113.741
# 10 46536.602
# 11 46251.411
# 12 46255.189999999995
# 13 46305.36
# 14 46412.057
# 15 46386.149
# 16 45570.089
# 17 45869.724
# 18 45760.722
# 19 45334.206
# 20 45191.311
# xgb
# 0 46098.403000000006
# 1 46080.681
# 2 46143.987
# 3 46085.998999999996
# 4 45682.663
# 5 45735.39
# 6 45841.806
# 7 45872.986
# 8 45887.075
# 9 46020.739
# 10 46085.213
# 11 45451.919
# 12 45457.31999999999
# 13 45323.464
# 14 46370.824
# 15 45327.666000000005
# 16 42848.663
# 17 42666.12000000001
# 18 42735.925
# 19 42531.879
# 20 42562.261
# dt
# 0 45896.630000000005
# 1 45954.416000000005
# 2 45866.072
# 3 45844.915
# 4 46280.307
# 5 47209.509000000005
# 6 46955.427
# 7 46502.311
# 8 46564.947
# 9 46640.759
# 10 46852.51400000001
# 11 46399.73
# 12 46551.151
# 13 46543.905
# 14 46172.095
# 15 46365.76700000001
# 16 46110.265
# ...

# %%
print('lightgbm')
gp_aof1_lightgbm_mean_ten = mean_ten_list(gp_aof_external_4_v11_T_th[0:30])  ## 0
print('xgb')
gp_aof1_xgb_mean_ten = mean_ten_list(gp_aof_external_4_v11_T_th[30:60])  ## 18
print('dt')
gp_aof1_dt_mean_ten = mean_ten_list(gp_aof_external_4_v11_T_th[60:90])  ##1
print('gbm')
gp_aof1_gbm_mean_ten = mean_ten_list(gp_aof_external_4_v11_T_th[90:120])  ##19
print('rf')
gp_aof1_rf_mean_ten = mean_ten_list(gp_aof_external_4_v11_T_th[120:150])  ## 10
print('ridge')
gp_aof1_ridge_mean_ten = mean_ten_list(gp_aof_external_4_v11_T_th[150:180])  ## 9
print('lasso')
gp_aof1_ridge_mean_ten = mean_ten_list(gp_aof_external_4_v11_T_th[180:210])  ## 9
print('lr')  
gp_aof1_lr_mean_ten = mean_ten_list(gp_aof_external_4_v11_T_th[210:240])  ##  1
# Out:
# lightgbm
# 0 45319.128000000004
# 1 45191.30500000001
# 2 44916.746
# 3 45055.066999999995
# 4 45012.299
# 5 45127.012
# 6 45449.282
# 7 45854.761000000006
# 8 46572.07399999999
# 9 45651.401
# 10 46829.553
# 11 46522.687
# 12 46553.911
# 13 46532.304000000004
# 14 46620.583
# 15 46506.457
# 16 46562.075
# 17 46168.377
# 18 46105.013999999996
# 19 45962.806
# 20 45870.663
# xgb
# 0 46223.86
# 1 46109.463
# 2 45822.21799999999
# 3 46020.159999999996
# 4 46074.615999999995
# 5 46283.996
# 6 46341.668999999994
# 7 46297.83
# 8 45822.907999999996
# 9 45299.447
# 10 45661.829000000005
# 11 44958.79
# 12 45486.6
# 13 45272.352
# 14 45033.94499999999
# 15 44461.439
# 16 44527.073
# 17 44680.814999999995
# 18 45259.737
# 19 46687.5
# 20 45627.958000000006
# dt
# 0 46859.969
# 1 46395.037
# 2 44282.143
# 3 43355.274999999994
# 4 42387.907
# 5 42377.578
# 6 42178.42199999999
# 7 42583.352999999996
# 8 43001.432
# 9 43190.604999999996
# 10 44120.621999999996
# 11 44587.583999999995
# ...

# %% [markdown]
# ---

# %%
for i in range(8):
    x1 = gp_aof_external_4_v21_th[0+i*30:30+i*30]
    x2 = gp_aof_external_4_v21_T_th[0+i*30:30+i*30]
#     print(x1.mean())
#     print(x2.mean())

    print(sp.stats.ttest_ind(x1, x2, equal_var=True, alternative='greater'))
# Out:
# Ttest_indResult(statistic=8.519058799945993, pvalue=4.157036867989819e-12)
# Ttest_indResult(statistic=-1.1769851577472645, pvalue=0.8779954645995678)
# Ttest_indResult(statistic=-0.2075293964213508, pvalue=0.5818383049035919)
# Ttest_indResult(statistic=6.629659079835426, pvalue=6.1210828344262295e-09)
# Ttest_indResult(statistic=0.6843764973680236, pvalue=0.24823154038877016)
# Ttest_indResult(statistic=1.2846179104617497, pvalue=0.1020164718098282)
# Ttest_indResult(statistic=1.1527836865457517, pvalue=0.12686409794982806)
# Ttest_indResult(statistic=-0.19534598671533984, pvalue=0.5770975834766493)

# %% [markdown]
# ## AOF 1:0

# %%
# aof1:0 
# default_rdb_external_4_th (90)  10
# gp_rdb_external_4_v2_th (240)  8개 모델별로 10개 
# gp_rdb_external_4_v2_T_th (240)  8개 모델별로 10개
# gp_T_rdb_external_4.csv [전체 gp]

# # rdb 1:0 internal -> configfile 확인용
# gp_aof_internal_4_v2 = pd.read_csv('./result_data/gp_aof_internal_4_v2.csv', sep=',')  # 개별
# gp_aof_internal_4_v2_T = gp_rdb_internal_4_v2[120:]  # T 

# rdb 1:0 external  15개씩
gp_aof_external_4_v21 = pd.read_csv('./result_data/gp_aof_external_4_v21.csv', sep=',')
gp_aof_external_4_v21_th = gp_aof_external_4_v21['Gets_KB/sec'][0:240].values  # throughput 값 추출

# rdb 1:0 external  15개씩
gp_aof_external_4_T_v21 = pd.read_csv('./result_data/gp_aof_external_4_v21.csv', sep=',')
gp_aof_external_4_v21_T_th = gp_aof_external_4_T_v21['Gets_KB/sec'][240:].values  # throughput 값 추출

# rdb 1:0 default  15개씩  90개까지!!
default_aof_external_4 = pd.read_csv('./result_data/default_aof_external_4.csv', sep=',')  
default_aof_external_4_th_Total = default_aof_external_4['Gets_KB/sec'].values # throughput 값 추출
default_aof2_external_4_th = default_aof_external_4_th_Total[90:]

# %%
default_aof2_mean_ten = mean_ten_list(default_aof2_external_4_th)  ## 0
# Out:
# 0 45349.175
# 1 46088.848000000005
# 2 45173.566
# 3 44393.046
# 4 44735.075
# 5 44635.843
# 6 44389.436
# 7 44256.808000000005
# 8 44248.52099999999
# 9 44398.962
# 10 43976.831999999995
# 11 44354.535
# 12 45199.157999999996
# 13 46064.78600000001
# 14 45975.03799999999
# 15 45941.060000000005
# 16 46052.141
# 17 46345.38
# 18 46334.05300000001
# 19 46022.298
# 20 46235.795
# 21 45609.156
# 22 45850.441000000006
# 23 45612.186
# 24 46006.990999999995
# 25 45991.384000000005
# 26 46157.348
# 27 45813.82
# 28 45638.001000000004
# 29 45558.223000000005
# 30 45524.831999999995
# 31 45904.953
# 32 45889.127
# 33 46267.577000000005
# 34 45734.653999999995
# 35 45817.686
# 36 45451.488
# 37 45684.993
# 38 45822.205
# 39 45353.5
# 40 45567.55
# 41 45344.299
# 42 45287.344
# 43 44891.731
# 44 45647.341
# 45 44829.367000000006
# 46 44508.941
# 47 44480.699
# 48 44242.159
# 49 44927.856
# 50 44581.66799999999
# 51 45053.31800000001
# 52 43819.996
# 53 43821.596999999994
# ...

# %%
print('lightgbm')
gp_aof2_lightgbm_mean_ten = mean_ten_list(gp_aof_external_4_v21_th[0:30])  ## 0
print('xgb')
gp_aof2_xgb_mean_ten = mean_ten_list(gp_aof_external_4_v21_th[30:60])  ## 18
print('dt')
gp_aof2_dt_mean_ten = mean_ten_list(gp_aof_external_4_v21_th[60:90])  ##1
print('gbm')
gp_aof2_gbm_mean_ten = mean_ten_list(gp_aof_external_4_v21_th[90:120])  ##19
print('rf')
gp_aof2_rf_mean_ten = mean_ten_list(gp_aof_external_4_v21_th[120:150])  ## 10
print('ridge')
gp_aof2_ridge_mean_ten = mean_ten_list(gp_aof_external_4_v21_th[150:180])  ## 9
print('lasso')
gp_aof2_ridge_mean_ten = mean_ten_list(gp_aof_external_4_v21_th[180:210])  ## 9
print('lr')  
gp_aof2_lr_mean_ten = mean_ten_list(gp_aof_external_4_v21_th[210:240])  ##  1
# Out:
# lightgbm
# 0 45220.503
# 1 45452.515
# 2 45821.922000000006
# 3 44955.608
# 4 44973.6
# 5 44831.741
# 6 44653.745
# 7 44459.429000000004
# 8 44101.62300000001
# 9 44477.759000000005
# 10 44455.364
# 11 44171.611999999994
# 12 44174.382999999994
# 13 45282.78
# 14 44661.763
# 15 44775.828
# 16 44854.898
# 17 44882.141
# 18 44686.97000000001
# 19 44213.798
# 20 43750.964
# xgb
# 0 43336.63
# 1 43846.519
# 2 44330.763
# 3 44828.394
# 4 43868.341
# 5 44088.17599999999
# 6 43935.960999999996
# 7 44111.924
# 8 44250.992000000006
# 9 44358.538
# 10 44034.067
# 11 43908.28199999999
# 12 44304.541
# 13 44666.955
# 14 45183.899
# 15 43759.026
# 16 43867.861000000004
# 17 43289.634999999995
# 18 43640.831999999995
# 19 43320.490999999995
# 20 43455.593
# dt
# 0 44640.087
# 1 44594.986000000004
# 2 44360.344999999994
# 3 44284.963
# 4 44867.136
# 5 44370.717000000004
# 6 45954.422999999995
# 7 45447.279
# 8 47099.909
# 9 47258.763
# 10 47032.545000000006
# 11 45396.90700000001
# ...

# %%
print('lightgbm')
gp_aof2_lightgbm_mean_ten = mean_ten_list(gp_aof_external_4_v21_T_th[0:30])  ## 0
print('xgb')
gp_aof2_xgb_mean_ten = mean_ten_list(gp_aof_external_4_v21_T_th[30:60])  ## 18
print('dt')
gp_aof2_dt_mean_ten = mean_ten_list(gp_aof_external_4_v21_T_th[60:90])  ##1
print('gbm')
gp_aof2_gbm_mean_ten = mean_ten_list(gp_aof_external_4_v21_T_th[90:120])  ##19
print('rf')
gp_aof2_rf_mean_ten = mean_ten_list(gp_aof_external_4_v21_T_th[120:150])  ## 10
print('ridge')
gp_aof2_ridge_mean_ten = mean_ten_list(gp_aof_external_4_v21_T_th[150:180])  ## 9
print('lasso')
gp_aof2_ridge_mean_ten = mean_ten_list(gp_aof_external_4_v21_T_th[180:210])  ## 9
print('lr')  
gp_aof2_lr_mean_ten = mean_ten_list(gp_aof_external_4_v21_T_th[210:240])  ##  1
# Out:
# lightgbm
# 0 35818.961
# 1 36428.316000000006
# 2 36268.898
# 3 36191.307
# 4 38133.387
# 5 37985.115000000005
# 6 38118.297999999995
# 7 37893.227
# 8 37618.918999999994
# 9 37978.974
# 10 38497.842000000004
# 11 38169.704000000005
# 12 37851.604999999996
# 13 37981.367
# 14 36961.60599999999
# 15 36632.342
# 16 36582.329000000005
# 17 36849.582
# 18 37092.3
# 19 37213.261
# 20 37147.691
# xgb
# 0 45494.340000000004
# 1 44415.871999999996
# 2 44034.628
# 3 44112.157999999996
# 4 45303.85600000001
# 5 45283.85199999999
# 6 44822.694
# 7 45072.812
# 8 45259.863
# 9 45497.77099999999
# 10 45544.801999999996
# 11 46123.486
# 12 46029.401
# 13 45829.590000000004
# 14 45741.11899999999
# 15 44909.11
# 16 45024.778999999995
# 17 44431.351
# 18 44209.322
# 19 43801.964
# 20 43632.859000000004
# dt
# 0 44829.05099999999
# 1 44334.90699999999
# 2 44324.21
# 3 44066.748999999996
# 4 44501.278000000006
# 5 44625.67
# 6 44351.569
# 7 45173.361
# 8 45062.253000000004
# 9 45673.893000000004
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 분석용

# %%
# rdb 1:1 디폴트 10개별로 값 확인
mean_ten_list(default_rdb_external_4_th)
# Out:
# 0 57467.329000000005
# 1 58244.219
# 2 57693.363
# 3 57015.605
# 4 56920.344
# 5 56282.439
# 6 56466.744000000006
# 7 58164.35399999999
# 8 58344.01399999999
# 9 57912.426
# 10 57150.998
# 11 56705.91199999999
# 12 56380.751000000004
# 13 56149.48
# 14 55422.96699999999
# 15 54711.105
# 16 55198.090000000004
# 17 54963.87999999999
# 18 54178.56499999999
# 19 54298.928
# 20 55511.23100000001
# 21 56522.30500000001
# 22 57347.971999999994
# 23 58233.39600000001
# 24 58794.286
# 25 59043.797000000006
# 26 58987.30299999999
# 27 59018.80099999999
# 28 59710.221999999994
# 29 59816.07200000001
# 30 60874.427
# 31 59838.599
# 32 60030.102
# 33 59658.56299999999
# 34 60234.06799999999
# 35 61428.382
# 36 61353.757
# 37 60792.337
# 38 60066.873999999996
# 39 60507.36699999999
# 40 59405.448
# 41 60260.795
# 42 59740.498
# 43 59415.342000000004
# 44 58826.16399999999
# 45 58204.226
# 46 56996.143000000004
# 47 54432.998
# 48 55161.284999999996
# 49 55161.01900000001
# 50 56214.109
# ...

# %%
gp_rdb_external_4_v1_th_dict1 = mean_ten_list(gp_rdb_external_4_v1_th[30:60])
# Out:
# 0 56282.203
# 1 56480.825
# 2 55777.451
# 3 56217.587
# 4 56031.826
# 5 56312.275
# 6 56209.067
# 7 56140.288
# 8 56457.134
# 9 54711.926
# 10 54383.056000000004
# 11 55131.384999999995
# 12 55752.251000000004
# 13 55870.933999999994
# 14 55684.4
# 15 56580.688
# 16 57264.234
# 17 57985.634
# 18 58518.614
# 19 60100.9
# 20 61443.755000000005

# %%
gp_rdb_external_4_v1_th_dict1

def ranksums_default_gp(gp_dict, default_list):
        for key, val in gp_dict.items():
            ranksums_stats, ranksums_pval = stats.ranksums(val, default_list)
            if ranksums_pval < 0.05:
                print(key, end=' ')
                print(val.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-6635609a89aa> in <module>
# ----> 1 gp_rdb_external_4_v1_th_dict1
#       2
#       3 def ranksums_default_gp(gp_dict, default_list):
#       4         for key, val in gp_dict.items():
#       5             ranksums_stats, ranksums_pval = stats.ranksums(val, default_list)
#
# NameError: name 'gp_rdb_external_4_v1_th_dict1' is not defined

# %%
ranksums_default_gp(gp_rdb_external_4_v1_th_dict1, default_rdb_external_4_th[0:10])

# %%
x1 = gp_rdb_external_4_v1_th[19:29]
x2 = default_rdb_external_4_th
stats.ranksums(x1, x2)
# Out:
# RanksumsResult(statistic=1.4017433746762795, pvalue=0.1609918931745763)

# %%
# 평균
def mean_ten_list(data):
    mean_dict = {}
    len_data = len(data)
    count = len_data - 10+1
    for i in range(count):
        print(i, end=' ')
        print(data[i:i+10].mean())
        mean_dict[i] = data[i:i+10]
    return mean_dict
    


# 정규성 검정
# def shapiro_ten_list(data):
#     shapiro_dict = {}
#     len_data = len(data)
#     count = len_data - 10+1
#     for i in range(count):
#         shapiro_stats, shapiro_pval = stats.shapiro(data[i:i+10])
#         if shapiro_pval < 0.05:
#             shapiro_dict[i] = data[i:i+10]
    
#     return shapiro_dict

# shapiro_ten_list(gp_rdb_external_4_v1_th)

# %%
# # t test
# x1 = gp_rdb_external_4_v1.iloc[0:10]['Gets_KB/sec']
# x2 = default_rdb_external_4.iloc[20:30]['Gets_KB/sec']
# sp.stats.ttest_ind(x1, x2, equal_var=True)

# # 순위합
# x1 = gp_rdb_external_4_v1.iloc[75:85]['Gets_KB/sec']
# x2 = default_rdb_external_4.iloc[20:30]['Gets_KB/sec']
# stats.ranksums(x1, x2)

## 등분산
# stats.levene(lightgbm_list[0], default_list[0])
# Out:
# RanksumsResult(statistic=1.0583005244258363, pvalue=0.28991845394256976)

# %%
# # lightgbm
# print(gp_rdb_internal_4_v1.iloc[0]['config_file'][57:])
# print(gp_rdb_external_4_v1.iloc[0:30]['Gets_KB/sec'].mean())

# print(gp_rdb_internal_4_v1.iloc[30]['config_file'][57:])
# print(gp_rdb_external_4_v1.iloc[30:60]['Gets_KB/sec'].mean())

# print(gp_rdb_internal_4_v1.iloc[60]['config_file'][57:])
# print(gp_rdb_external_4_v1.iloc[60:90]['Gets_KB/sec'].mean())

# print(gp_rdb_internal_4_v1.iloc[120]['config_file'][57:])
# print(gp_rdb_external_4_v1.iloc[120:150]['Gets_KB/sec'].mean())

# print(gp_rdb_internal_4_v1.iloc[150]['config_file'][57:])
# print(gp_rdb_external_4_v1.iloc[150:180]['Gets_KB/sec'].mean())

# print(gp_rdb_internal_4_v1.iloc[180]['config_file'][57:])
# print(gp_rdb_external_4_v1.iloc[180:210]['Gets_KB/sec'].mean())

# print(gp_rdb_internal_4_v1.iloc[210]['config_file'][57:])
# print(gp_rdb_external_4_v1.iloc[210:240]['Gets_KB/sec'].mean())
# Out:
# /config_rdb1_lightgbm.conf
# 59304.13300000001
# /config_rdb1_xgb.conf
# 57369.67133333334
# /config_rdb1_dt.conf
# 58932.126000000004
# /config_rdb1_rf.conf
# 59909.356999999975
# /config_rdb1_ridge.conf
# 59977.013666666666
# /config_rdb1_lasso.conf
# 58809.895666666685
# /config_rdb1_lr.conf
# 57478.48

# %%
# # default 1
# print(default_rdb_external_4.iloc[0:30]['Gets_KB/sec'].mean())
# print(default_rdb_external_4.iloc[30:60]['Gets_KB/sec'].mean())
# print(default_rdb_external_4.iloc[60:90]['Gets_KB/sec'].mean())
# Out:
# 56709.85266666666
# 58831.327999999994
# 58019.88766666666

# %%
# from itertools import combinations

# default_list = []
# lightgbm_list = []
# for i in combinations(list(default_rdb_external_4.iloc[0:30]['Gets_KB/sec']), 10):
#     shapiro_stats, shapiro_pval = stats.shapiro(i)
#     if shapiro_pval < 0.05:
#         print(shapiro_pval)
#         default_list.append(i)
#         break

# for i in combinations(list(gp_rdb_external_4_v1.iloc[0:30]['Gets_KB/sec']), 10):
#     shapiro_stats, shapiro_pval = stats.shapiro(i)
#     if shapiro_pval < 0.05:
#         print(shapiro_pval)
#         lightgbm_list.append(i)
#         break
# Out:
# 0.04549872875213623
# 0.04723963886499405
